# %%
import requests
import json
import pandas as pd

# %% [markdown]
# # Darksky API
# 1000 calls per day
#
# https://darksky.net/dev/docs

# %%
DARKSKY_KEY = "d07fa9b030dfc7ae1a1897828f0e01de"

# %%
# Get current location in latitude and longitude
import geocoder
g = geocoder.ip('me')
print(g.latlng)
LAT = g.latlng[0]
LONG = g.latlng[1]
# Out:
# [52.374, 4.8897]

# %%
def get_features(longitude,latitude):
#Gets a json_object with the current weather on the given coordinate
    URL = "https://api.darksky.net/forecast/" + DARKSKY_KEY + "/" + str(latitude) + "," + str(longitude) +"?exclude=daily,alerts"
    r = requests.get(URL)
    json_str = r.content.decode("utf8").replace("'", '"')
    json_object = json.loads(json_str)
    return json_object

# %%
obj = get_features(LONG, LAT)

# %%
obj

# %% [markdown]
# # NS API
# 1000 calls per 5 minutes (I think)
#
# Probably not going to use this API since we have the Google Directions API

# %%
NS_REIS_KEY = "e6a58e80f2b444efbc97fc302485c199"

# %%
# Code from https://apiportal.ns.nl/docs/services/reisinformatie-api/operations/getStations?
import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {
    # Request headers
    'Ocp-Apim-Subscription-Key': NS_REIS_KEY,
}

params = urllib.parse.urlencode({
})

try:
    conn = http.client.HTTPSConnection('gateway.apiportal.ns.nl')
    conn.request("GET", "/reisinformatie-api/api/v2/stations?%s" % params, "{body}", headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))
# Out:
# b'{"payload":[{"UICCode":"8002084","stationType":"SNELTREIN_STATION","EVACode":"8000139","code":"MGZB","sporen":[],"synoniemen":["Gunzburg"],"heeftFaciliteiten":true,"heeftVertrektijden":true,"heeftReisassistentie":false,"namen":{"lang":"G\xc3\xbcnzburg","middel":"G\xc3\xbcnzburg","kort":"G\xc3\xbcnzburg"},"land":"D","lat":48.460226,"lng":10.278707,"radius":0,"naderenRadius":0,"ingangsDatum":"2018-12-16","nearbyMeLocationId":{"value":"MGZB","type":"stationV2"}},{"UICCode":"8002140","stationType":"SNELTREIN_STATION","EVACode":"8000013","code":"MA","sporen":[],"synoniemen":[],"heeftFaciliteiten":true,"heeftVertrektijden":true,"heeftReisassistentie":false,"namen":{"lang":"Augsburg Hbf","middel":"Augsburg Hbf","kort":"Augsburg"},"land":"D","lat":48.3654307143927,"lng":10.88547706604,"radius":0,"naderenRadius":0,"ingangsDatum":"2018-12-16","nearbyMeLocationId":{"value":"MA","type":"stationV2"}},{"UICCode":"8003004","stationType":"KNOOPPUNT_INTERCITY_STATION","EVACode":"8010255","code":"BHF","sporen":[],"synoniemen":[],"heeftFaciliteiten":true,"heeftVertrektijden":true,"heeftReisassistentie":false,"namen":{"lang":"Berlin Ostbahnhof","middel":"Berlin Ostbhf","kort":"Berlin Ost"},"land":"D","lat":52.5104989,"lng":13.4346995,"radius":0,"naderenRadius":0,"ingangsDatum":"2018-12-16","nearbyMeLocationId":{"value":"BHF","type":"stationV2"}},{"UICCode":"8003025","stationType":"INTERCITY_STATION","EVACode":"8010404","code":"BSPD","sporen":[],"synoniemen":[],"heeftFaciliteiten":true,"heeftVertrektijden":true,"heeftReisassistentie":false,"namen":{"lang":"Berlin-Spandau","middel":"Berlin-Spandau","kort":"Berlin-Spa"},"land":"D","lat":52.5343152,"lng":13.1989467,"radius":0,"naderenRadius":0,"ingangsDatum":"2018-12-16","nearbyMeLocationId":{"value":"BSPD","type":"stationV2"}},{"UICCode":"8007799","stationType":"INTERCITY_STATION","EVACode":"8011102","code":"GSB","sporen":[],"synoniemen":[],"heeftFaciliteiten":true,"heeftVertrektijden":true,"heeftReisassistentie":false,"namen":{"lang":"Berlin Gesundbrunnen","middel":"Berlin Gesundbr.","kort":"Berlin Gsb"},"land":"D","lat":52.5486327,"lng":13.3904267,"radius":0,"naderenRadius":0,"ingangsDatum":"2018-12-16","nearbyMeLocationId":{"value":"GSB","type":"stationV2"}},{"UICCode":"8008016","stationType":"STOPTREIN_STATION","EVACode":"8000037","code":"ESRT","sporen":[],"synoniemen":[],"heeftFaciliteiten":true,"heeftVertrektijden":true,"heeftReisassistentie":false,"namen":{"lang":"Schwerte (Ruhr)","middel":"Schwerte (R)","kort":"Schwerte"},"land":"D","lat":51.442281,"lng":7.55896,"radius":0,"naderenRadius":0,"ingangsDatum":"2018-12-16","nearbyMeLocationId":{"value":"ESRT","type":"stationV2"}},{"UICCode":"8008073","stationType":"KNOOPPUNT_SNELTREIN_STATION","EVACode":"8000142","code":"HAGEN","sporen":[],"synoniemen":[],"heeftFaciliteiten":true,"heeftVertrektijden":true,"heeftReisassistentie":false,"namen":{"lang":"Hagen Hbf","middel":"Hagen Hbf","kort":"Hagen"},"land":"D","lat":51.362747,"lng":7.460249,"radius":0,"naderenRadius":0,"ingangsDatum":"2013-05-29","nearbyMeLocationId":{"value":"HAGEN","type":"stationV2"}},{"UICCode":"8008082","stationType":"STOPTREIN_STATION","EVACode":"8006718","code":"WUPPV","sporen":[],"synoniemen":[],"heeftFaciliteiten":true,"heeftVertrektijden":true,"heeftReisassistentie":false,"namen":{"lang":"Wuppertal-Vohwinkel","middel":"Wupp-Vohwinkel","kort":"Wupp-Vohw"},"land":"D","lat":51.23351,"lng":7.07237,"radius":0,"naderenRadius":0,"ingangsDatum":"2018-12-16","nearbyMeLocationId":{"value":"WUPPV","type":"stationV2"}},{"UICCode":"8008094","stationType":"MEGA_STATION","EVACode":"8000085","code":"DUSSEL","sporen":[],"synoniemen":["Dusseldorf"],"heeftFaciliteiten":true,"heeftVertrektijden":true,"heeftReisassistentie":false,"namen":{"lang":"D\xc3\xbcsseldorf Hbf","middel":"D\xc3\xbcsseldorf Hbf","kort":"D\xc3\xbcsseldrf"},"land":"D","lat":51.220146,"lng":6.793137,"radius":0,"naderenRadius":0,"ingangsDatum":"2017-06-07","nearbyMeLocationId":{"value":"DUSSEL","type":"stationV2"}},{"UICC ...

# %%
import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {
    # Request headers
    'Authorization': '',
    'Ocp-Apim-Subscription-Key': NS_REIS_KEY,
}

params = urllib.parse.urlencode({
    # Request parameters
    'originLat': 52.371269,
    'originLng': 4.966500,
    'destinationLat': 52.374,
    'destinationLng': 4.8897,
})

try:
    conn = http.client.HTTPSConnection('gateway.apiportal.ns.nl')
    conn.request("GET", "/reisinformatie-api/api/v3/trips?%s" % params, "{body}", headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))
# Out:
# b'{"timestamp":"2022-03-11T08:28:15+0000","path":"/api/v3/trips","message":"Bad Request","requestId":"e463e538-685a-4d55-8cb9-48b02874b4e7","code":400,"errors":[{"message":"Met deze API key mogen geen deur-tot-deur adviezen opgevraagd worden \\uD83D\\uDE41","type":"API_KEY_NOT_ALLOWED_TO_PLAN_DOOR_TO_DOOR","lang":"nl"}]}'

# %% [markdown]
# # Google Maps API

# %%
from time import mktime
import datetime

GOOGLE_MAPS_KEY = "AIzaSyAJiy_cEFCxdnBHlWCvnnlVBj6zcTfZfSk"
ORIG = "Kees Broekmanstraat 459"
DEST = "Science Park 904"
date = datetime.datetime.now()
TIME = mktime(date.timetuple())
TIME = str(int(1647943620))

# %%
import requests

url = "https://maps.googleapis.com/maps/api/directions/json?origin=" + ORIG + "&destination=" + DEST + "&mode=transit&departure_time=" + TIME + "&key=" + GOOGLE_MAPS_KEY + "&alternatives=true"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "geocoded_waypoints" : [
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJQVBmqjEJxkcRwfoQ6b0fcWM",
#          "types" : [ "street_address" ]
#       },
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJfRjQ7EQJxkcRhUk-uSK84Lo",
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "routes" : [
#       {
#          "bounds" : {
#             "northeast" : {
#                "lat" : 52.37229689999999,
#                "lng" : 4.965470499999999
#             },
#             "southwest" : {
#                "lat" : 52.3522513,
#                "lng" : 4.9389157
#             }
#          },
#          "copyrights" : "Map data ©2022",
#          "legs" : [
#             {
#                "arrival_time" : {
#                   "text" : "11:48am",
#                   "time_zone" : "Europe/Amsterdam",
#                   "value" : 1647946116
#                },
#                "departure_time" : {
#                   "text" : "11:26am",
#                   "time_zone" : "Europe/Amsterdam",
#                   "value" : 1647944792
#                },
#                "distance" : {
#                   "text" : "4.9 km",
#                   "value" : 4883
#                },
#                "duration" : {
#                   "text" : "22 mins",
#                   "value" : 1324
#                },
#                "end_address" : "Science Park 904, 1098 XH Amsterdam, Netherlands",
#                "end_location" : {
#                   "lat" : 52.3535392,
#                   "lng" : 4.956428300000001
#                },
#                "start_address" : "Kees Broekmanstraat 459, 1095 Amsterdam, Netherlands",
#                "start_location" : {
#                   "lat" : 52.3717958,
#                   "lng" : 4.965470499999999
#                },
#                "steps" : [
#                   {
#                      "distance" : {
#                         "text" : "0.4 km",
#                         "value" : 400
#                      },
#                      "duration" : {
#                         "text" : "5 mins",
#                         "value" : 328
#                      },
#                      "end_location" : {
#                         "lat" : 52.3712922,
#                         "lng" : 4.9621277
#                      },
#                      "html_instructions" : "Walk to Amsterdam, Zuiderzeeweg",
#                      "polyline" : {
#                         "points" : "wzs~Heyh]ABGRQd@AHEJKZGVGXUz@JHNJNLNHADMn@Ox@CHG^OfAGh@EVP@@?F?R?P@T?`@?CXACAVANCVETbBC"
#                      },
#                      "start_location" : {
#                         "lat" : 52.3717958,
#                         "lng" : 4.965470499999999
#                      },
#                      "steps" : [
#                         {
#                            "distance" : {
#                               "text" : "90 m",
#                               "value" : 90
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 65
#                            },
#                            "end_location" : {
#                               "lat" : 52.372227,
#                               "lng" : 4.9643617
#                            },
#                            "html_instructions" : "Head \u003cb\u003enorthwest\u003c/b\u003e on \u003cb\u003eKees Broekmanstraat\u003c/b\u003e toward \u003cb\u003eNida Senffstraat\u003c/b\u003e",
#                            "polyline" : {
#                               "points" : "wzs~Heyh]ABGRQd@AHEJKZGVGXUz@"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3717958,
#                               "lng" : 4.965470499999999
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "41 m",
#                               "value" : 41
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 30
#                            },
#                            "end_location" : {
#                               "lat" : 52.3719283,
#                               "lng" : 4.9641283
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003ePiet Dickentmanbrug\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "m}s~Hgrh]JHNJNLNH"
#                            },
#                            "start_location" : {
#                               "lat" : 52.372227,
#                               "lng" : 4.9643617
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "0.1 km",
#                               "value" : 108
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 77
#                            },
#                            "end_location" : {
#                               "lat" : 52.37229689999999,
#                               "lng" : 4.9626652
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "q{s~Hyph]ADMn@Ox@CHG^OfAGh@EV"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3719283,
#                               "lng" : 4.9641283
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "68 m",
#                               "value" : 68
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 69
#                            },
#                            "end_location" : {
#                               "lat" : 52.3716872,
#                               "lng" : 4.9626458
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "{}s~Hugh]P@@?F?R?P@T?`@?"
#                            },
#                            "start_location" : {
#                               "lat" : 52.37229689999999,
#                               "lng" : 4.9626652
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "38 m",
#                               "value" : 38
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 47
#                            },
#                            "end_location" : {
#                               "lat" : 52.3717885,
#                               "lng" : 4.962108499999999
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "azs~Hqgh]CXACAVANCVET"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3716872,
#                               "lng" : 4.9626458
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "55 m",
#                               "value" : 55
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 40
#                            },
#                            "end_location" : {
#                               "lat" : 52.3712922,
#                               "lng" : 4.9621277
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e\u003cdiv style=\"font-size:0.9em\"\u003eDestination will be on the left\u003c/div\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "uzs~Hedh]bBC"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3717885,
#                               "lng" : 4.962108499999999
#                            },
#                            "travel_mode" : "WALKING"
#                         }
#                      ],
#                      "travel_mode" : "WALKING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "2.3 km",
#                         "value" : 2293
#                      },
#                      "duration" : {
#                         "text" : "5 mins",
#                         "value" : 289
#                      },
#                      "end_location" : {
#                         "lat" : 52.3615858,
#                         "lng" : 4.9389233
#                      },
#                      "html_instructions" : "Bus towards Amstelstation",
#                      "polyline" : {
#                         "points" : "qws~Hsdh]?UV@PAl@AF?p@DD@D@B?D?F?HAHAJAHAHAF?RAn@CB?JCfDC@?X?N@^?J@L@H?F@HBNBVFZJPFJDPJZRJHJFJJRPRTDDFFFHLRPXJRJPDNLVN`@Pf@Nd@Lh@FZDPBPBP@@Db@Hp@Dl@Df@Bt@Bb@?BB\\?D?D@H@RHzBJzB@`@@RDt@?B?NBn@Bl@NjDHvBThFBx@Bb@@T?F@Z@ZBh@@f@@h@@B@n@@x@@t@?J?DAZ?N?X?\\?h@?b@?@Ab@AVAT?X?RBZFrADPFRJXFNBJDJFJFHHJFLHHFDDBDBFBHFNFp@Pn@RHB`@LTFXHr@Rf@Nr@LLFHFHJFFBFFJDJDPBL?FBNDh@Dh@HtAJrA\\dEFt@@NJvA^tFBd@FbAFt@Bf@Dr@BZHrA@VHdA@H@JB^@LDf@Dl@B?"
#                      },
#                      "start_location" : {
#                         "lat" : 52.37129299999999,
#                         "lng" : 4.962181999999999
#                      },
#                      "transit_details" : {
#                         "arrival_stop" : {
#                            "location" : {
#                               "lat" : 52.3615858,
#                               "lng" : 4.9389233
#                            },
#                            "name" : "Amsterdam, Molukkenstraat"
#                         },
#                         "arrival_time" : {
#                            "text" : "11:36am",
#                            "time_zone" : "Europe/Amsterdam",
#                            "value" : 1647945409
#                         },
#                         "departure_stop" : {
#                            "location" : {
#                               "lat" : 52.37129299999999,
#                               "lng" : 4.962181999999999
#                            },
#                            "name" : "Amsterdam, Zuiderzeeweg"
#                         },
#                         "departure_time" : {
#                            "text" : "11:32am",
#                            "time_zone" : "Europe/Amsterdam",
#                            "value" : 1647945120
#                         },
#                         "headsign" : "Amstelstation",
#                         "line" : {
#                            "agencies" : [
#                               {
#                                  "name" : "GVB",
#                                  "phone" : "011 31 900 8011",
#                                  "url" : "http://www.gvb.nl/"
#                               }
#                            ],
#                            "name" : "Station Noord - Amstelstation",
#                            "short_name" : "37",
#                            "url" : "http://www.gvb.nl/lijn/bus/37",
#                            "vehicle" : {
#                               "icon" : "//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png",
#                               "name" : "Bus",
#                               "type" : "BUS"
#                            }
#                         },
#                         "num_stops" : 3
#                      },
#                      "travel_mode" : "TRANSIT"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "61 m",
#                         "value" : 61
#                      },
#                      "duration" : {
#                         "text" : "1 min",
#                         "value" : 44
#                      },
#                      "end_location" : {
#                         "lat" : 52.3614741,
#                         "lng" : 4.9396397
#                      },
#                      "html_instructions" : "Walk to Amsterdam, Molukkenstraat",
#                      "polyline" : {
#                         "points" : "ezq~Hqsc]P?ImAGu@?A"
#                      },
#                      "start_location" : {
#                         "lat" : 52.3614679,
#                         "lng" : 4.938971599999999
#                      },
#                      "steps" : [
#                         {
#                            "distance" : {
#                               "text" : "61 m",
#                               "value" : 61
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 44
#                            },
#                            "end_location" : {
#                               "lat" : 52.3614741,
#                               "lng" : 4.9396397
#                            },
#                            "html_instructions" : "Head \u003cb\u003eeast\u003c/b\u003e on \u003cb\u003eInsulindeweg\u003c/b\u003e toward \u003cb\u003eMolukkenstraat\u003c/b\u003e\u003cdiv style=\"font-size:0.9em\"\u003eDestination will be on the right\u003c/div\u003e",
#                            "polyline" : {
#                               "points" : "ezq~Hqsc]P?ImAGu@?A"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3614679,
#                               "lng" : 4.938971599999999
#                            },
#                            "travel_mode" : "WALKING"
#                         }
#                      ],
#                      "travel_mode" : "WALKING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "2.0 km",
#                         "value" : 1973
#                      },
#                      "duration" : {
#                         "text" : "5 mins",
#                         "value" : 281
#                      },
#                      "end_location" : {
#                         "lat" : 52.35433039999999,
#                         "lng" : 4.958298099999999
#                      },
#                      "html_instructions" : "Bus towards Amstelstation",
#                      "polyline" : {
#                         "points" : "szq~Hwtc]FAC]Gu@E_@ZO^ITIb@MZIn@ObAYl@Od@Ex@U`AWXOFEb@M@AH@D?D?JCDAJ?\\Kz@SH?H?PCAQ?w@@Q?G?G@I@]NsBPgCVcDHaA?A@O?SBgA?G@i@@g@?U@U?]@K@M@E@OBKBI?AFSBE@GFKFOFMBEBGZm@P_@Xg@dDmGbAiBJMrC_FHQ`@}@n@iAd@}@LSVc@xBiEn@qALS\\q@b@}@Vi@Zq@Ra@NYPYHYMUGMCEGECEEGEGCEGKUg@OY]q@IOc@{@GKCIEKGKEKGSUm@AEAAAAGGSi@Ma@CGEMEIAEISc@gAYo@]w@O]DI"
#                      },
#                      "start_location" : {
#                         "lat" : 52.36153669999999,
#                         "lng" : 4.9391624
#                      },
#                      "transit_details" : {
#                         "arrival_stop" : {
#                            "location" : {
#                               "lat" : 52.35433039999999,
#                               "lng" : 4.958298099999999
#                            },
#                            "name" : "Science Park Terra"
#                         },
#                         "arrival_time" : {
#                            "text" : "11:46am",
#                            "time_zone" : "Europe/Amsterdam",
#                            "value" : 1647946002
#                         },
#                         "departure_stop" : {
#                            "location" : {
#                               "lat" : 52.36153669999999,
#                               "lng" : 4.9391624
#                            },
#                            "name" : "Amsterdam, Molukkenstraat"
#                         },
#                         "departure_time" : {
#                            "text" : "11:42am",
#                            "time_zone" : "Europe/Amsterdam",
#                            "value" : 1647945721
#                         },
#                         "headsign" : "Amstelstation",
#                         "line" : {
#                            "agencies" : [
#                               {
#                                  "name" : "GVB",
#                                  "phone" : "011 31 900 8011",
#                                  "url" : "http://www.gvb.nl/"
#                               }
#                            ],
#                            "name" : "Amstelstation - Muiderpoortstation",
#                            "short_name" : "40",
#                            "url" : "http://www.gvb.nl/lijn/bus/40",
#                            "vehicle" : {
#                               "icon" : "//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png",
#                               "name" : "Bus",
#                               "type" : "BUS"
#                            }
#                         },
#                         "num_stops" : 4
#                      },
#                      "travel_mode" : "TRANSIT"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "0.2 km",
#                         "value" : 156
#                      },
#                      "duration" : {
#                         "text" : "2 mins",
#                         "value" : 114
#                      },
#                      "end_location" : {
#                         "lat" : 52.3535392,
#                         "lng" : 4.956428300000001
#                      },
#                      "html_instructions" : "Walk to Science Park 904, 1098 XH Amsterdam, Netherlands",
#                      "polyline" : {
#                         "points" : "smp~Hglg]N\\Xl@KNBJRf@LPZx@HR@DFNFPL`@Rf@?F@F"
#                      },
#                      "start_location" : {
#                         "lat" : 52.3543424,
#                         "lng" : 4.9582806
#                      },
#                      "steps" : [
#                         {
#                            "distance" : {
#                               "text" : "0.1 km",
#                               "value" : 149
#                            },
#                            "duration" : {
#                               "text" : "2 mins",
#                               "value" : 109
#                            },
#                            "end_location" : {
#                               "lat" : 52.3535522,
#                               "lng" : 4.9565101
#                            },
#                            "html_instructions" : "Head \u003cb\u003esouthwest\u003c/b\u003e",
#                            "polyline" : {
#                               "points" : "smp~Hglg]N\\Xl@KNBJRf@LPZx@HR@DFNFPL`@Rf@"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3543424,
#                               "lng" : 4.9582806
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "7 m",
#                               "value" : 7
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 5
#                            },
#                            "end_location" : {
#                               "lat" : 52.3535392,
#                               "lng" : 4.956428300000001
#                            },
#                            "html_instructions" : "Slight \u003cb\u003eright\u003c/b\u003e\u003cdiv style=\"font-size:0.9em\"\u003eDestination will be on the right\u003c/div\u003e",
#                            "maneuver" : "turn-slight-right",
#                            "polyline" : {
#                               "points" : "uhp~Heag]?F@F"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3535522,
#                               "lng" : 4.9565101
#                            },
#                            "travel_mode" : "WALKING"
#                         }
#                      ],
#                      "travel_mode" : "WALKING"
#                   }
#                ],
#                "traffic_speed_entry" : [],
#                "via_waypoint" : []
#             }
#          ],
#          "overview_polyline" : {
#             "points" : "wzs~Heyh]]fAa@xAUz@JH^XNHAD]hBc@zCEVP@H?|A@CXACCf@Il@bBC?I?UV@~@CdAHP?h@GtAGNChDCtABh@FtA^dAn@~@z@b@j@n@nA\\x@`@lA^hBThBRnDPfEvAb^NfFB`CAbBEnEJnBLd@\\`A`@n@VRVNzBp@dCr@zA\\VN\\f@Nr@lAxOv@vLTlDd@|GDl@B?VIP?QcCM|AFAC]MuAtBq@|DcAd@Ex@U`AWXOj@SJ?VCPAxA_@R?PCAQ@iA?Od@cHb@wFDmCBqBFo@Nk@LYVk@lFcKlFiJpAgCr@qAnEsItBkEb@{@Zs@a@o@S[kA_Cy@aB[w@[w@GGSi@Qi@Wq@kBmEDIABh@jAKNBJ`@x@n@bBh@bB@F"
#          },
#          "summary" : "",
#          "warnings" : [
#             "Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths."
#          ],
#          "waypoint_order" : []
#       },
#       {
#          "bounds" : {
#             "northeast" : {
#                "lat" : 52.37229689999999,
#                "lng" : 4.965470499999999
#             },
#             "southwest" : {
#                "lat" : 52.3534209,
#                "lng" : 4.9438328
#             }
#          },
#          "copyrights" : "Map data ©2022",
#          "legs" : [
#             {
#                "arrival_time" : {
#                   "text" : "11:45am",
#                   "time_zone" : "Europe/Amsterdam",
#                   "value" : 1647945958
#                },
#                "departure_time" : {
#                   "text" : "11:16am",
#                   "time_zone" : "Europe/Amsterdam",
#                   "value" : 1647944192
#                },
#                "distance" : {
#                   "text" : "3.9 km",
#                   "value" : 3917
#                },
#                "duration" : {
#                   "text" : "29 mins",
#                   "value" : 1766
#                },
#                "end_address" : "Science Park 904, 1098 XH Amsterdam, Netherlands",
#                "end_location" : {
#                   "lat" : 52.3535392,
#                   "lng" : 4.956428300000001
#                },
#                "start_address" : "Kees Broekmanstraat 459, 1095 Amsterdam, Netherlands",
#                "start_location" : {
#                   "lat" : 52.3717958,
#                   "lng" : 4.965470499999999
#                },
#                "steps" : [
#                   {
#                      "distance" : {
#                         "text" : "0.4 km",
#                         "value" : 400
#                      },
#                      "duration" : {
#                         "text" : "5 mins",
#                         "value" : 328
#                      },
#                      "end_location" : {
#                         "lat" : 52.3712922,
#                         "lng" : 4.9621277
#                      },
#                      "html_instructions" : "Walk to Amsterdam, Zuiderzeeweg",
#                      "polyline" : {
#                         "points" : "wzs~Heyh]ABGRQd@AHEJKZGVGXUz@JHNJNLNHADMn@Ox@CHG^OfAGh@EVP@@?F?R?P@T?`@?CXACAVANCVETbBC"
#                      },
#                      "start_location" : {
#                         "lat" : 52.3717958,
#                         "lng" : 4.965470499999999
#                      },
#                      "steps" : [
#                         {
#                            "distance" : {
#                               "text" : "90 m",
#                               "value" : 90
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 65
#                            },
#                            "end_location" : {
#                               "lat" : 52.372227,
#                               "lng" : 4.9643617
#                            },
#                            "html_instructions" : "Head \u003cb\u003enorthwest\u003c/b\u003e on \u003cb\u003eKees Broekmanstraat\u003c/b\u003e toward \u003cb\u003eNida Senffstraat\u003c/b\u003e",
#                            "polyline" : {
#                               "points" : "wzs~Heyh]ABGRQd@AHEJKZGVGXUz@"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3717958,
#                               "lng" : 4.965470499999999
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "41 m",
#                               "value" : 41
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 30
#                            },
#                            "end_location" : {
#                               "lat" : 52.3719283,
#                               "lng" : 4.9641283
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003ePiet Dickentmanbrug\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "m}s~Hgrh]JHNJNLNH"
#                            },
#                            "start_location" : {
#                               "lat" : 52.372227,
#                               "lng" : 4.9643617
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "0.1 km",
#                               "value" : 108
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 77
#                            },
#                            "end_location" : {
#                               "lat" : 52.37229689999999,
#                               "lng" : 4.9626652
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "q{s~Hyph]ADMn@Ox@CHG^OfAGh@EV"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3719283,
#                               "lng" : 4.9641283
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "68 m",
#                               "value" : 68
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 69
#                            },
#                            "end_location" : {
#                               "lat" : 52.3716872,
#                               "lng" : 4.9626458
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "{}s~Hugh]P@@?F?R?P@T?`@?"
#                            },
#                            "start_location" : {
#                               "lat" : 52.37229689999999,
#                               "lng" : 4.9626652
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "38 m",
#                               "value" : 38
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 47
#                            },
#                            "end_location" : {
#                               "lat" : 52.3717885,
#                               "lng" : 4.962108499999999
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "azs~Hqgh]CXACAVANCVET"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3716872,
#                               "lng" : 4.9626458
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "55 m",
#                               "value" : 55
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 40
#                            },
#                            "end_location" : {
#                               "lat" : 52.3712922,
#                               "lng" : 4.9621277
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e\u003cdiv style=\"font-size:0.9em\"\u003eDestination will be on the left\u003c/div\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "uzs~Hedh]bBC"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3717885,
#                               "lng" : 4.962108499999999
#                            },
#                            "travel_mode" : "WALKING"
#                         }
#                      ],
#                      "travel_mode" : "WALKING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "1.9 km",
#                         "value" : 1939
#                      },
#                      "duration" : {
#                         "text" : "4 mins",
#                         "value" : 240
#                      },
#                      "end_location" : {
#                         "lat" : 52.3622864,
#                         "lng" : 4.9439991
#                      },
#                      "html_instructions" : "Bus towards Amstelstation",
#                      "polyline" : {
#                         "points" : "qws~Hsdh]?UV@PAl@AF?p@DD@D@B?D?F?HAHAJAHAHAF?RAn@CB?JCfDC@?X?N@^?J@L@H?F@HBNBVFZJPFJDPJZRJHJFJJRPRTDDFFFHLRPXJRJPDNLVN`@Pf@Nd@Lh@FZDPBPBP@@Db@Hp@Dl@Df@Bt@Bb@?BB\\?D?D@H@RHzBJzB@`@@RDt@?B?NBn@Bl@NjDHvBThFBx@Bb@@T?F@Z@ZBh@@f@@h@@B@n@@x@@t@?J?DAZ?N?X?\\?h@?b@?@Ab@AVAT?X?RBZFrADPFRJXFNBJDJFJFHHJFLHHFDDBDBFBHFNFp@Pn@RHB`@LTFXHr@Rf@Nr@LLFHFHJFFBFFJDJDPBL?FBNDh@Dh@HtAJrA\\dEC?"
#                      },
#                      "start_location" : {
#                         "lat" : 52.37129299999999,
#                         "lng" : 4.962181999999999
#                      },
#                      "transit_details" : {
#                         "arrival_stop" : {
#                            "location" : {
#                               "lat" : 52.3622864,
#                               "lng" : 4.9439991
#                            },
#                            "name" : "Amsterdam, Soembawastraat"
#                         },
#                         "arrival_time" : {
#                            "text" : "11:26am",
#                            "time_zone" : "Europe/Amsterdam",
#                            "value" : 1647944760
#                         },
#                         "departure_stop" : {
#                            "location" : {
#                               "lat" : 52.37129299999999,
#                               "lng" : 4.962181999999999
#                            },
#                            "name" : "Amsterdam, Zuiderzeeweg"
#                         },
#                         "departure_time" : {
#                            "text" : "11:22am",
#                            "time_zone" : "Europe/Amsterdam",
#                            "value" : 1647944520
#                         },
#                         "headsign" : "Amstelstation",
#                         "line" : {
#                            "agencies" : [
#                               {
#                                  "name" : "GVB",
#                                  "phone" : "011 31 900 8011",
#                                  "url" : "http://www.gvb.nl/"
#                               }
#                            ],
#                            "name" : "Station Noord - Amstelstation",
#                            "short_name" : "37",
#                            "url" : "http://www.gvb.nl/lijn/bus/37",
#                            "vehicle" : {
#                               "icon" : "//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png",
#                               "name" : "Bus",
#                               "type" : "BUS"
#                            }
#                         },
#                         "num_stops" : 2
#                      },
#                      "travel_mode" : "TRANSIT"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "1.6 km",
#                         "value" : 1578
#                      },
#                      "duration" : {
#                         "text" : "20 mins",
#                         "value" : 1184
#                      },
#                      "end_location" : {
#                         "lat" : 52.3535392,
#                         "lng" : 4.956428300000001
#                      },
#                      "html_instructions" : "Walk to Science Park 904, 1098 XH Amsterdam, Netherlands",
#                      "polyline" : {
#                         "points" : "q~q~Hmrd]HNPMvA_@JEnAa@HCh@Oj@O?O?IFo@Du@Dk@@a@DHvCp@L@LHDDpCh@h@HZHRK@E@IB?N@Z@F?^oANm@XeAGR`@YRBRPBKJUBGFODKBGBEZm@R_@DIP_@dDkGbAgBBEN]hCqE@ANUVk@HYjAuB?SDEJKIMKSQSCWGKNYOUCEAI?I?Q?[@{@?IBMb@iBAm@?KA}@?a@?{Bl@i@DEFGFIBK`@sANi@Le@Je@@GHWBIK[KY?A"
#                      },
#                      "start_location" : {
#                         "lat" : 52.3621656,
#                         "lng" : 4.9439145
#                      },
#                      "steps" : [
#                         {
#                            "distance" : {
#                               "text" : "0.2 km",
#                               "value" : 175
#                            },
#                            "duration" : {
#                               "text" : "2 mins",
#                               "value" : 132
#                            },
#                            "end_location" : {
#                               "lat" : 52.3606537,
#                               "lng" : 4.9444359
#                            },
#                            "html_instructions" : "Head \u003cb\u003esoutheast\u003c/b\u003e on \u003cb\u003eSemarangstraat\u003c/b\u003e toward \u003cb\u003eInsulindeweg\u003c/b\u003e",
#                            "polyline" : {
#                               "points" : "q~q~Hmrd]HNPMvA_@JEnAa@HCh@Oj@O"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3621656,
#                               "lng" : 4.9439145
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "67 m",
#                               "value" : 67
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 49
#                            },
#                            "end_location" : {
#                               "lat" : 52.3605056,
#                               "lng" : 4.9454153
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003eTidorestraat\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "auq~Hwud]?O?IFo@Du@Dk@@a@DH"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3606537,
#                               "lng" : 4.9444359
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "0.2 km",
#                               "value" : 234
#                            },
#                            "duration" : {
#                               "text" : "3 mins",
#                               "value" : 171
#                            },
#                            "end_location" : {
#                               "lat" : 52.3583995,
#                               "lng" : 4.9448262
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e onto \u003cb\u003eKramatweg\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "etq~H{{d]vCp@L@LHDDpCh@h@HZHRK"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3605056,
#                               "lng" : 4.9454153
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "13 m",
#                               "value" : 13
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 11
#                            },
#                            "end_location" : {
#                               "lat" : 52.358382,
#                               "lng" : 4.944909399999999
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003eValentijnkade\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "_gq~Hexd]@E@I"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3583995,
#                               "lng" : 4.9448262
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "35 m",
#                               "value" : 35
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 23
#                            },
#                            "end_location" : {
#                               "lat" : 52.3581028,
#                               "lng" : 4.9448899
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "{fq~Huxd]B?N@Z@F?"
#                            },
#                            "start_location" : {
#                               "lat" : 52.358382,
#                               "lng" : 4.944909399999999
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "91 m",
#                               "value" : 91
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 61
#                            },
#                            "end_location" : {
#                               "lat" : 52.3575974,
#                               "lng" : 4.9458955
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "ceq~Hqxd]^oANm@XeAGR`@Y"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3581028,
#                               "lng" : 4.9448899
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "0.5 km",
#                               "value" : 529
#                            },
#                            "duration" : {
#                               "text" : "7 mins",
#                               "value" : 412
#                            },
#                            "end_location" : {
#                               "lat" : 52.35419169999999,
#                               "lng" : 4.951223800000001
#                            },
#                            "html_instructions" : "Take the crosswalk",
#                            "polyline" : {
#                               "points" : "_bq~H{~d]RBRPBKJUBGFODKBGBEZm@R_@DIP_@dDkGbAgBBEN]hCqE@ANUVk@HYjAuB?SDEJKIM"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3575974,
#                               "lng" : 4.9458955
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "38 m",
#                               "value" : 38
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 40
#                            },
#                            "end_location" : {
#                               "lat" : 52.3544038,
#                               "lng" : 4.9516034
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e at \u003cb\u003eKruislaan\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "ulp~Hc`f]KSQSCWGK"
#                            },
#                            "start_location" : {
#                               "lat" : 52.35419169999999,
#                               "lng" : 4.951223800000001
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "19 m",
#                               "value" : 19
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 14
#                            },
#                            "end_location" : {
#                               "lat" : 52.3543195,
#                               "lng" : 4.9517307
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e toward \u003cb\u003eScience Park\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "_np~Hobf]NY"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3544038,
#                               "lng" : 4.9516034
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "0.2 km",
#                               "value" : 202
#                            },
#                            "duration" : {
#                               "text" : "2 mins",
#                               "value" : 146
#                            },
#                            "end_location" : {
#                               "lat" : 52.3542413,
#                               "lng" : 4.9545398
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003eScience Park\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "omp~Hicf]OUCEAI?I?Q?[@{@?IBMb@iBAm@?KA}@?a@?{B"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3543195,
#                               "lng" : 4.9517307
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "0.2 km",
#                               "value" : 152
#                            },
#                            "duration" : {
#                               "text" : "2 mins",
#                               "value" : 109
#                            },
#                            "end_location" : {
#                               "lat" : 52.3534209,
#                               "lng" : 4.9561459
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "_mp~H{tf]l@i@DEFGFIBK`@sANi@Le@Je@@GHWBI"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3542413,
#                               "lng" : 4.9545398
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "23 m",
#                               "value" : 23
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 16
#                            },
#                            "end_location" : {
#                               "lat" : 52.3535392,
# ...
#                         {
#                            "distance" : {
#                               "text" : "29 m",
#                               "value" : 29
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 22
#                            },
#                            "end_location" : {
#                               "lat" : 52.35778750000001,
#                               "lng" : 4.952927499999999
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "sdq~H{jf]D?^@F?"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3580228,
#                               "lng" : 4.952942
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "0.2 km",
#                               "value" : 244
#                            },
#                            "duration" : {
#                               "text" : "3 mins",
#                               "value" : 168
#                            },
#                            "end_location" : {
#                               "lat" : 52.3574072,
#                               "lng" : 4.956366399999999
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "ecq~Hyjf]TmOf@uBLk@"
#                            },
#                            "start_location" : {
#                               "lat" : 52.35778750000001,
#                               "lng" : 4.952927499999999
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "0.2 km",
#                               "value" : 182
#                            },
#                            "duration" : {
#                               "text" : "2 mins",
#                               "value" : 130
#                            },
#                            "end_location" : {
#                               "lat" : 52.3562328,
#                               "lng" : 4.954475
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "y`q~Hi`g]Xj@DHBBPV@RJV@BBFDFP\\JRx@`BFLFLBBHPFLLTBDBDFK"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3574072,
#                               "lng" : 4.956366399999999
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "54 m",
#                               "value" : 54
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 42
#                            },
#                            "end_location" : {
#                               "lat" : 52.3558894,
#                               "lng" : 4.9549306
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "myp~Hmtf]Ve@Z_@NU"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3562328,
#                               "lng" : 4.954475
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "37 m",
#                               "value" : 37
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 27
#                            },
#                            "end_location" : {
#                               "lat" : 52.3556768,
#                               "lng" : 4.9545739
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "iwp~Hiwf]h@fA"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3558894,
#                               "lng" : 4.9549306
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "24 m",
#                               "value" : 24
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 19
#                            },
#                            "end_location" : {
#                               "lat" : 52.3555275,
#                               "lng" : 4.9548384
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "_vp~Hauf]\\u@"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3556768,
#                               "lng" : 4.9545739
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "36 m",
#                               "value" : 36
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 27
#                            },
#                            "end_location" : {
#                               "lat" : 52.355298,
#                               "lng" : 4.9544554
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "aup~Hwvf]BBVh@P\\"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3555275,
#                               "lng" : 4.9548384
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "76 m",
#                               "value" : 76
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 56
#                            },
#                            "end_location" : {
#                               "lat" : 52.35477900000001,
#                               "lng" : 4.9551415
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "ssp~Hktf]J?HKVc@x@wA"
#                            },
#                            "start_location" : {
#                               "lat" : 52.355298,
#                               "lng" : 4.9544554
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "52 m",
#                               "value" : 52
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 38
#                            },
#                            "end_location" : {
#                               "lat" : 52.35443189999999,
#                               "lng" : 4.9546468
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "kpp~Hsxf]t@xADFH?"
#                            },
#                            "start_location" : {
#                               "lat" : 52.35477900000001,
#                               "lng" : 4.9551415
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "17 m",
#                               "value" : 17
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 12
#                            },
#                            "end_location" : {
#                               "lat" : 52.3543168,
#                               "lng" : 4.95474
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "enp~Hquf]BOBC?A@?@?B?DB"
#                            },
#                            "start_location" : {
#                               "lat" : 52.35443189999999,
#                               "lng" : 4.9546468
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "46 m",
#                               "value" : 46
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 33
#                            },
#                            "end_location" : {
#                               "lat" : 52.3540948,
#                               "lng" : 4.9551766
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "omp~Hcvf]H_@@QBW@C?A@?B?FFFKDC"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3543168,
#                               "lng" : 4.95474
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "45 m",
#                               "value" : 45
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 32
#                            },
#                            "end_location" : {
#                               "lat" : 52.35371199999999,
#                               "lng" : 4.9553536
#                            },
#                            "html_instructions" : "Slight \u003cb\u003eright\u003c/b\u003e",
#                            "maneuver" : "turn-slight-right",
#                            "polyline" : {
#                               "points" : "alp~H{xf]JCFEJEHEHEVE"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3540948,
#                               "lng" : 4.9551766
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "69 m",
#                               "value" : 69
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 50
#                            },
#                            "end_location" : {
#                               "lat" : 52.3534209,
#                               "lng" : 4.9561459
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "uip~H}yf]Ni@Le@Je@@GHWBI"
#                            },
#                            "start_location" : {
#                               "lat" : 52.35371199999999,
#                               "lng" : 4.9553536
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "23 m",
#                               "value" : 23
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 16
#                            },
#                            "end_location" : {
#                               "lat" : 52.3535392,
#                               "lng" : 4.956428300000001
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e\u003cdiv style=\"font-size:0.9em\"\u003eDestination will be on the right\u003c/div\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "{gp~H}~f]K[KY?A"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3534209,
#                               "lng" : 4.9561459
#                            },
#                            "travel_mode" : "WALKING"
#                         }
#                      ],
#                      "travel_mode" : "WALKING"
#                   }
#                ],
#                "traffic_speed_entry" : [],
#                "via_waypoint" : []
#             }
#          ],
#          "overview_polyline" : {
#             "points" : "wzs~Heyh]]fAa@xAUz@JH^XNHAD]hBc@zCEVP@H?|A@bFHp@HRHRDfABjDB@APAp@?fAJ|@Tr@Zp@d@f@b@b@f@Zf@b@v@n@hBd@~A^`CXvEP`ELfDDTBLDbA@LB@A_BD??B@F?NBBn@Jb@PHpDJj@P\\lCzClC~CRb@Ll@F|@F~AN`AHZJXDADAP?b@Dj@PRd@X~@Ft@AJl@NP@BAb@qBJWLCHB`@X\\o@HEh@KhA@RCTERMPOp@_A|@oANMNU^Yh@CTBPHb@ZNTv@lBJSNk@RG^ABkDD?f@@TmOf@uBLk@Xj@HLPV@RLZf@`ApB|DBDFKr@eANUh@fA\\u@BBh@fAJ?HKpA{Bz@`BH?BOBELBPmADAFFFKPGf@WVENi@XkAJ_@BIK[K["
#          },
#          "summary" : "Flevopark",
#          "warnings" : [
#             "Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths."
#          ],
#          "waypoint_order" : []
#       }
#    ],
#    "status" : "OK"
# }

# %%
json_resp = json.loads(response.text)
# for item in json_resp:
#     print(item)
    
for item in json_resp['routes']:
    print(item)
    print('\n')
# Out:
# {'bounds': {'northeast': {'lat': 52.37229689999999, 'lng': 4.965470499999999}, 'southwest': {'lat': 52.3522513, 'lng': 4.9389157}}, 'copyrights': 'Map data ©2022', 'legs': [{'arrival_time': {'text': '11:48am', 'time_zone': 'Europe/Amsterdam', 'value': 1647946116}, 'departure_time': {'text': '11:26am', 'time_zone': 'Europe/Amsterdam', 'value': 1647944792}, 'distance': {'text': '4.9 km', 'value': 4883}, 'duration': {'text': '22 mins', 'value': 1324}, 'end_address': 'Science Park 904, 1098 XH Amsterdam, Netherlands', 'end_location': {'lat': 52.3535392, 'lng': 4.956428300000001}, 'start_address': 'Kees Broekmanstraat 459, 1095 Amsterdam, Netherlands', 'start_location': {'lat': 52.3717958, 'lng': 4.965470499999999}, 'steps': [{'distance': {'text': '0.4 km', 'value': 400}, 'duration': {'text': '5 mins', 'value': 328}, 'end_location': {'lat': 52.3712922, 'lng': 4.9621277}, 'html_instructions': 'Walk to Amsterdam, Zuiderzeeweg', 'polyline': {'points': 'wzs~Heyh]ABGRQd@AHEJKZGVGXUz@JHNJNLNHADMn@Ox@CHG^OfAGh@EVP@@?F?R?P@T?`@?CXACAVANCVETbBC'}, 'start_location': {'lat': 52.3717958, 'lng': 4.965470499999999}, 'steps': [{'distance': {'text': '90 m', 'value': 90}, 'duration': {'text': '1 min', 'value': 65}, 'end_location': {'lat': 52.372227, 'lng': 4.9643617}, 'html_instructions': 'Head <b>northwest</b> on <b>Kees Broekmanstraat</b> toward <b>Nida Senffstraat</b>', 'polyline': {'points': 'wzs~Heyh]ABGRQd@AHEJKZGVGXUz@'}, 'start_location': {'lat': 52.3717958, 'lng': 4.965470499999999}, 'travel_mode': 'WALKING'}, {'distance': {'text': '41 m', 'value': 41}, 'duration': {'text': '1 min', 'value': 30}, 'end_location': {'lat': 52.3719283, 'lng': 4.9641283}, 'html_instructions': 'Turn <b>left</b> onto <b>Piet Dickentmanbrug</b>', 'maneuver': 'turn-left', 'polyline': {'points': 'm}s~Hgrh]JHNJNLNH'}, 'start_location': {'lat': 52.372227, 'lng': 4.9643617}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.1 km', 'value': 108}, 'duration': {'text': '1 min', 'value': 77}, 'end_location': {'lat': 52.37229689999999, 'lng': 4.9626652}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'q{s~Hyph]ADMn@Ox@CHG^OfAGh@EV'}, 'start_location': {'lat': 52.3719283, 'lng': 4.9641283}, 'travel_mode': 'WALKING'}, {'distance': {'text': '68 m', 'value': 68}, 'duration': {'text': '1 min', 'value': 69}, 'end_location': {'lat': 52.3716872, 'lng': 4.9626458}, 'html_instructions': 'Turn <b>left</b>', 'maneuver': 'turn-left', 'polyline': {'points': '{}s~Hugh]P@@?F?R?P@T?`@?'}, 'start_location': {'lat': 52.37229689999999, 'lng': 4.9626652}, 'travel_mode': 'WALKING'}, {'distance': {'text': '38 m', 'value': 38}, 'duration': {'text': '1 min', 'value': 47}, 'end_location': {'lat': 52.3717885, 'lng': 4.962108499999999}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'azs~Hqgh]CXACAVANCVET'}, 'start_location': {'lat': 52.3716872, 'lng': 4.9626458}, 'travel_mode': 'WALKING'}, {'distance': {'text': '55 m', 'value': 55}, 'duration': {'text': '1 min', 'value': 40}, 'end_location': {'lat': 52.3712922, 'lng': 4.9621277}, 'html_instructions': 'Turn <b>left</b><div style="font-size:0.9em">Destination will be on the left</div>', 'maneuver': 'turn-left', 'polyline': {'points': 'uzs~Hedh]bBC'}, 'start_location': {'lat': 52.3717885, 'lng': 4.962108499999999}, 'travel_mode': 'WALKING'}], 'travel_mode': 'WALKING'}, {'distance': {'text': '2.3 km', 'value': 2293}, 'duration': {'text': '5 mins', 'value': 289}, 'end_location': {'lat': 52.3615858, 'lng': 4.9389233}, 'html_instructions': 'Bus towards Amstelstation', 'polyline': {'points': 'qws~Hsdh]?UV@PAl@AF?p@DD@D@B?D?F?HAHAJAHAHAF?RAn@CB?JCfDC@?X?N@^?J@L@H?F@HBNBVFZJPFJDPJZRJHJFJJRPRTDDFFFHLRPXJRJPDNLVN`@Pf@Nd@Lh@FZDPBPBP@@Db@Hp@Dl@Df@Bt@Bb@?BB\\?D?D@H@RHzBJzB@`@@RDt@?B?NBn@Bl@NjDHvBThFBx@Bb@@T?F@Z@ZBh@@f@@h@@B@n@@x@@t@?J?DAZ?N?X?\\?h@?b@?@Ab@AVAT?X?RBZFrADPFRJXFNBJDJFJFHHJFLHHFDDBDBFBHFNFp@Pn@RHB`@LTFXHr@Rf@Nr@LLFHFHJFFBFFJDJDPBL?FBNDh@Dh@HtAJrA\\dEFt@@NJvA^tFBd@ ...
#
#
# {'bounds': {'northeast': {'lat': 52.37229689999999, 'lng': 4.965470499999999}, 'southwest': {'lat': 52.3534209, 'lng': 4.9438328}}, 'copyrights': 'Map data ©2022', 'legs': [{'arrival_time': {'text': '11:45am', 'time_zone': 'Europe/Amsterdam', 'value': 1647945958}, 'departure_time': {'text': '11:16am', 'time_zone': 'Europe/Amsterdam', 'value': 1647944192}, 'distance': {'text': '3.9 km', 'value': 3917}, 'duration': {'text': '29 mins', 'value': 1766}, 'end_address': 'Science Park 904, 1098 XH Amsterdam, Netherlands', 'end_location': {'lat': 52.3535392, 'lng': 4.956428300000001}, 'start_address': 'Kees Broekmanstraat 459, 1095 Amsterdam, Netherlands', 'start_location': {'lat': 52.3717958, 'lng': 4.965470499999999}, 'steps': [{'distance': {'text': '0.4 km', 'value': 400}, 'duration': {'text': '5 mins', 'value': 328}, 'end_location': {'lat': 52.3712922, 'lng': 4.9621277}, 'html_instructions': 'Walk to Amsterdam, Zuiderzeeweg', 'polyline': {'points': 'wzs~Heyh]ABGRQd@AHEJKZGVGXUz@JHNJNLNHADMn@Ox@CHG^OfAGh@EVP@@?F?R?P@T?`@?CXACAVANCVETbBC'}, 'start_location': {'lat': 52.3717958, 'lng': 4.965470499999999}, 'steps': [{'distance': {'text': '90 m', 'value': 90}, 'duration': {'text': '1 min', 'value': 65}, 'end_location': {'lat': 52.372227, 'lng': 4.9643617}, 'html_instructions': 'Head <b>northwest</b> on <b>Kees Broekmanstraat</b> toward <b>Nida Senffstraat</b>', 'polyline': {'points': 'wzs~Heyh]ABGRQd@AHEJKZGVGXUz@'}, 'start_location': {'lat': 52.3717958, 'lng': 4.965470499999999}, 'travel_mode': 'WALKING'}, {'distance': {'text': '41 m', 'value': 41}, 'duration': {'text': '1 min', 'value': 30}, 'end_location': {'lat': 52.3719283, 'lng': 4.9641283}, 'html_instructions': 'Turn <b>left</b> onto <b>Piet Dickentmanbrug</b>', 'maneuver': 'turn-left', 'polyline': {'points': 'm}s~Hgrh]JHNJNLNH'}, 'start_location': {'lat': 52.372227, 'lng': 4.9643617}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.1 km', 'value': 108}, 'duration': {'text': '1 min', 'value': 77}, 'end_location': {'lat': 52.37229689999999, 'lng': 4.9626652}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'q{s~Hyph]ADMn@Ox@CHG^OfAGh@EV'}, 'start_location': {'lat': 52.3719283, 'lng': 4.9641283}, 'travel_mode': 'WALKING'}, {'distance': {'text': '68 m', 'value': 68}, 'duration': {'text': '1 min', 'value': 69}, 'end_location': {'lat': 52.3716872, 'lng': 4.9626458}, 'html_instructions': 'Turn <b>left</b>', 'maneuver': 'turn-left', 'polyline': {'points': '{}s~Hugh]P@@?F?R?P@T?`@?'}, 'start_location': {'lat': 52.37229689999999, 'lng': 4.9626652}, 'travel_mode': 'WALKING'}, {'distance': {'text': '38 m', 'value': 38}, 'duration': {'text': '1 min', 'value': 47}, 'end_location': {'lat': 52.3717885, 'lng': 4.962108499999999}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'azs~Hqgh]CXACAVANCVET'}, 'start_location': {'lat': 52.3716872, 'lng': 4.9626458}, 'travel_mode': 'WALKING'}, {'distance': {'text': '55 m', 'value': 55}, 'duration': {'text': '1 min', 'value': 40}, 'end_location': {'lat': 52.3712922, 'lng': 4.9621277}, 'html_instructions': 'Turn <b>left</b><div style="font-size:0.9em">Destination will be on the left</div>', 'maneuver': 'turn-left', 'polyline': {'points': 'uzs~Hedh]bBC'}, 'start_location': {'lat': 52.3717885, 'lng': 4.962108499999999}, 'travel_mode': 'WALKING'}], 'travel_mode': 'WALKING'}, {'distance': {'text': '1.9 km', 'value': 1939}, 'duration': {'text': '4 mins', 'value': 240}, 'end_location': {'lat': 52.3622864, 'lng': 4.9439991}, 'html_instructions': 'Bus towards Amstelstation', 'polyline': {'points': 'qws~Hsdh]?UV@PAl@AF?p@DD@D@B?D?F?HAHAJAHAHAF?RAn@CB?JCfDC@?X?N@^?J@L@H?F@HBNBVFZJPFJDPJZRJHJFJJRPRTDDFFFHLRPXJRJPDNLVN`@Pf@Nd@Lh@FZDPBPBP@@Db@Hp@Dl@Df@Bt@Bb@?BB\\?D?D@H@RHzBJzB@`@@RDt@?B?NBn@Bl@NjDHvBThFBx@Bb@@T?F@Z@ZBh@@f@@h@@B@n@@x@@t@?J?DAZ?N?X?\\?h@?b@?@Ab@AVAT?X?RBZFrADPFRJXFNBJDJFJFHHJFLHHFDDBDBFBHFNFp@Pn@RHB`@LTFXHr@Rf@Nr@LLFHFHJFFBFFJDJDPBL?FBNDh@Dh@HtAJrA\\dEC?'}, 'start_l ...
#
#
# {'bounds': {'northeast': {'lat': 52.37229689999999, 'lng': 4.965470499999999}, 'southwest': {'lat': 52.3522513, 'lng': 4.9389157}}, 'copyrights': 'Map data ©2022', 'legs': [{'arrival_time': {'text': '12:03pm', 'time_zone': 'Europe/Amsterdam', 'value': 1647947016}, 'departure_time': {'text': '11:36am', 'time_zone': 'Europe/Amsterdam', 'value': 1647945392}, 'distance': {'text': '4.9 km', 'value': 4883}, 'duration': {'text': '27 mins', 'value': 1624}, 'end_address': 'Science Park 904, 1098 XH Amsterdam, Netherlands', 'end_location': {'lat': 52.3535392, 'lng': 4.956428300000001}, 'start_address': 'Kees Broekmanstraat 459, 1095 Amsterdam, Netherlands', 'start_location': {'lat': 52.3717958, 'lng': 4.965470499999999}, 'steps': [{'distance': {'text': '0.4 km', 'value': 400}, 'duration': {'text': '5 mins', 'value': 328}, 'end_location': {'lat': 52.3712922, 'lng': 4.9621277}, 'html_instructions': 'Walk to Amsterdam, Zuiderzeeweg', 'polyline': {'points': 'wzs~Heyh]ABGRQd@AHEJKZGVGXUz@JHNJNLNHADMn@Ox@CHG^OfAGh@EVP@@?F?R?P@T?`@?CXACAVANCVETbBC'}, 'start_location': {'lat': 52.3717958, 'lng': 4.965470499999999}, 'steps': [{'distance': {'text': '90 m', 'value': 90}, 'duration': {'text': '1 min', 'value': 65}, 'end_location': {'lat': 52.372227, 'lng': 4.9643617}, 'html_instructions': 'Head <b>northwest</b> on <b>Kees Broekmanstraat</b> toward <b>Nida Senffstraat</b>', 'polyline': {'points': 'wzs~Heyh]ABGRQd@AHEJKZGVGXUz@'}, 'start_location': {'lat': 52.3717958, 'lng': 4.965470499999999}, 'travel_mode': 'WALKING'}, {'distance': {'text': '41 m', 'value': 41}, 'duration': {'text': '1 min', 'value': 30}, 'end_location': {'lat': 52.3719283, 'lng': 4.9641283}, 'html_instructions': 'Turn <b>left</b> onto <b>Piet Dickentmanbrug</b>', 'maneuver': 'turn-left', 'polyline': {'points': 'm}s~Hgrh]JHNJNLNH'}, 'start_location': {'lat': 52.372227, 'lng': 4.9643617}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.1 km', 'value': 108}, 'duration': {'text': '1 min', 'value': 77}, 'end_location': {'lat': 52.37229689999999, 'lng': 4.9626652}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'q{s~Hyph]ADMn@Ox@CHG^OfAGh@EV'}, 'start_location': {'lat': 52.3719283, 'lng': 4.9641283}, 'travel_mode': 'WALKING'}, {'distance': {'text': '68 m', 'value': 68}, 'duration': {'text': '1 min', 'value': 69}, 'end_location': {'lat': 52.3716872, 'lng': 4.9626458}, 'html_instructions': 'Turn <b>left</b>', 'maneuver': 'turn-left', 'polyline': {'points': '{}s~Hugh]P@@?F?R?P@T?`@?'}, 'start_location': {'lat': 52.37229689999999, 'lng': 4.9626652}, 'travel_mode': 'WALKING'}, {'distance': {'text': '38 m', 'value': 38}, 'duration': {'text': '1 min', 'value': 47}, 'end_location': {'lat': 52.3717885, 'lng': 4.962108499999999}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'azs~Hqgh]CXACAVANCVET'}, 'start_location': {'lat': 52.3716872, 'lng': 4.9626458}, 'travel_mode': 'WALKING'}, {'distance': {'text': '55 m', 'value': 55}, 'duration': {'text': '1 min', 'value': 40}, 'end_location': {'lat': 52.3712922, 'lng': 4.9621277}, 'html_instructions': 'Turn <b>left</b><div style="font-size:0.9em">Destination will be on the left</div>', 'maneuver': 'turn-left', 'polyline': {'points': 'uzs~Hedh]bBC'}, 'start_location': {'lat': 52.3717885, 'lng': 4.962108499999999}, 'travel_mode': 'WALKING'}], 'travel_mode': 'WALKING'}, {'distance': {'text': '2.3 km', 'value': 2293}, 'duration': {'text': '5 mins', 'value': 289}, 'end_location': {'lat': 52.3615858, 'lng': 4.9389233}, 'html_instructions': 'Bus towards Amstelstation', 'polyline': {'points': 'qws~Hsdh]?UV@PAl@AF?p@DD@D@B?D?F?HAHAJAHAHAF?RAn@CB?JCfDC@?X?N@^?J@L@H?F@HBNBVFZJPFJDPJZRJHJFJJRPRTDDFFFHLRPXJRJPDNLVN`@Pf@Nd@Lh@FZDPBPBP@@Db@Hp@Dl@Df@Bt@Bb@?BB\\?D?D@H@RHzBJzB@`@@RDt@?B?NBn@Bl@NjDHvBThFBx@Bb@@T?F@Z@ZBh@@f@@h@@B@n@@x@@t@?J?DAZ?N?X?\\?h@?b@?@Ab@AVAT?X?RBZFrADPFRJXFNBJDJFJFHHJFLHHFDDBDBFBHFNFp@Pn@RHB`@LTFXHr@Rf@Nr@LLFHFHJFFBFFJDJDPBL?FBNDh@Dh@HtAJrA\\dEFt@@NJvA^tFBd@ ...
#
#
# {'bounds': {'northeast': {'lat': 52.37229689999999, 'lng': 4.965470499999999}, 'southwest': {'lat': 52.3534209, 'lng': 4.9504377}}, 'copyrights': 'Map data ©2022', 'legs': [{'distance': {'text': '3.5 km', 'value': 3473}, 'duration': {'text': '43 mins', 'value': 2605}, 'end_address': 'Science Park 904, 1098 XH Amsterdam, Netherlands', 'end_location': {'lat': 52.3535392, 'lng': 4.956428300000001}, 'start_address': 'Kees Broekmanstraat 459, 1095 Amsterdam, Netherlands', 'start_location': {'lat': 52.3717958, 'lng': 4.965470499999999}, 'steps': [{'distance': {'text': '3.5 km', 'value': 3473}, 'duration': {'text': '43 mins', 'value': 2605}, 'end_location': {'lat': 52.3535392, 'lng': 4.956428300000001}, 'html_instructions': 'Walk to Science Park 904, 1098 XH Amsterdam, Netherlands', 'polyline': {'points': 'wzs~Heyh]ABGRQd@AHEJKZGVGXUz@JHNJNLNHADMn@Ox@CHG^OfAGh@EVP@@?F?R?P@T?`@?nBB`A@b@?LBRBNBF@D?B@@?FBDBD@B@H@H@P?F?b@@`@@@?fA@D?r@@@?@?@A@ABAL?J?H?F?R?P@RBN@PBNBLDNDNDLDNHNFDBFDPJJHJHJHB@DFPNDFHHHHHJDHHJJN?@HLJRBDHNPb@FPFRL^FNBHJ\\Lf@DTF^F^Hj@?@Ft@LvBBf@@V?F@N?@@VB`@Bd@Bn@?FHlB@X@V@LBF@J@@?J?JBT@T@F?@?@?@@??@@??A?_@A]@??I?CAQD??B@B?BAF@F@@@@B@F?RBNDF@@@LDJFFhC@f@BPFXDLJN\\`@nBxBVZpAzANPRTDFBFBHDHBHBLBJ@H@J@H@J@Z@h@BZ@J?L@JBHBNDZDNBJJXDAB?@AB?L?H?F@H@F@\\HDBB@B@@DBBBFHR@@Nf@DJ@HBJ@H?H@TAJl@ND?J@@?@??ADQP{@DODSBG@EBE@CBA@AB?B?B@D@D@ZVVg@DGBCDABCBAD?ZE|@@J?FAJAJCHAHEHGFEHIJMd@q@^g@DGR[BCDEHGFMFGFIFEFEFCHAJAJAF@H@J@FBHDTLLLDFHLVh@^bAFKBG@EDWBGBEBABCDAD?TAH?BkDD?^@F?TmOf@uBLk@Xj@DHBBPV@RJV@BBFDFP\\JRx@`BFLFLBBHPFLLTBDBDFKVe@Z_@NUh@fA\\u@BBVh@P\\J?HKVc@x@wAt@xADFH?BOBC?A@?@?B?DBH_@@QBW@C?A@?B?FFFKDCJCFEJEHEHEVENi@Le@Je@@GHWBIK[KY?A'}, 'start_location': {'lat': 52.3717958, 'lng': 4.965470499999999}, 'steps': [{'distance': {'text': '90 m', 'value': 90}, 'duration': {'text': '1 min', 'value': 65}, 'end_location': {'lat': 52.372227, 'lng': 4.9643617}, 'html_instructions': 'Head <b>northwest</b> on <b>Kees Broekmanstraat</b> toward <b>Nida Senffstraat</b>', 'polyline': {'points': 'wzs~Heyh]ABGRQd@AHEJKZGVGXUz@'}, 'start_location': {'lat': 52.3717958, 'lng': 4.965470499999999}, 'travel_mode': 'WALKING'}, {'distance': {'text': '41 m', 'value': 41}, 'duration': {'text': '1 min', 'value': 30}, 'end_location': {'lat': 52.3719283, 'lng': 4.9641283}, 'html_instructions': 'Turn <b>left</b> onto <b>Piet Dickentmanbrug</b>', 'maneuver': 'turn-left', 'polyline': {'points': 'm}s~Hgrh]JHNJNLNH'}, 'start_location': {'lat': 52.372227, 'lng': 4.9643617}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.1 km', 'value': 108}, 'duration': {'text': '1 min', 'value': 77}, 'end_location': {'lat': 52.37229689999999, 'lng': 4.9626652}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'q{s~Hyph]ADMn@Ox@CHG^OfAGh@EV'}, 'start_location': {'lat': 52.3719283, 'lng': 4.9641283}, 'travel_mode': 'WALKING'}, {'distance': {'text': '1.0 km', 'value': 990}, 'duration': {'text': '13 mins', 'value': 770}, 'end_location': {'lat': 52.3657628, 'lng': 4.9564705}, 'html_instructions': 'Turn <b>left</b>', 'maneuver': 'turn-left', 'polyline': {'points': '{}s~Hugh]P@@?F?R?P@T?`@?nBB`A@b@?LBRBNBF@D?B@@?FBDBD@B@H@H@P?F?b@@`@@@?fA@D?r@@@?@?@A@ABAL?J?H?F?R?P@RBN@PBNBLDNDNDLDNHNFDBFDPJJHJHJHB@DFPNDFHHHHHJDHHJJN?@HLJRBDHNPb@FPFRL^FNBHJ\\Lf@DTF^F^Hj@?@Ft@LvBBf@@V?F@N?@@VB`@Bd@Bn@?FHlB@X@V@L'}, 'start_location': {'lat': 52.37229689999999, 'lng': 4.9626652}, 'travel_mode': 'WALKING'}, {'distance': {'text': '71 m', 'value': 71}, 'duration': {'text': '2 mins', 'value': 91}, 'end_location': {'lat': 52.3656656, 'lng': 4.9564185}, 'html_instructions': 'Slight <b>left</b> toward <b>Waterkeringpad</b><div style="font-size:0.9em">Take the stairs</div>', 'maneuver': 'turn-slight-left', 'polyline': {'points': '_ur~H}`g]BF@J@@?J?JBT@T@F?@?@?@@??@@??A?_@A]@??I?CAQ'}, 'start_location': {'lat': 52.3657628, 'lng': 4.9564705}, 'travel_mode': 'WALKING'}, {'distance': {'text': '12 m', 'value': 12}, 'duration': {'text': '1 min', 'value': 12}, 'end_location': {'lat': 52.36563 ...

# %%
route = json_resp['routes'][2]['legs'][0]
print(route['arrival_time'])
print(route['departure_time'])
print(route['distance']['text'])
print(route['duration']['text'])
print(route['start_address'].split(','))
print(route['end_address'])
print(route['end_location'])
# for item in route:
#     print(item)
# Out:
# {'text': '12:03pm', 'time_zone': 'Europe/Amsterdam', 'value': 1647947016}
# {'text': '11:36am', 'time_zone': 'Europe/Amsterdam', 'value': 1647945392}
# 4.9 km
# 27 mins
# ['Kees Broekmanstraat 459', ' 1095 Amsterdam', ' Netherlands']
# Science Park 904, 1098 XH Amsterdam, Netherlands
# {'lat': 52.3535392, 'lng': 4.956428300000001}

# %%
ts = int(route['arrival_time']['value'])
print(datetime.datetime.utcfromtimestamp(ts).strftime('%H:%M'))

ts = int(route['departure_time']['value'])
print(datetime.datetime.utcfromtimestamp(ts).strftime('%H:%M'))
# Out:
# 11:03
# 10:36

# %%
transit_modes = []

for step in json_resp['routes'][0]['legs'][0]['steps']:
    print(step['duration']['text'])
    print(step['distance']['text'])
    print(step['start_location'])
    print(step['end_location'])
    print(step['travel_mode'])

    if step['travel_mode'] == 'TRANSIT':
        print(step['transit_details']['departure_stop']['name'])
        print(step['transit_details']['departure_time']['text'])
        print(step['transit_details']['arrival_stop']['name'])
        print(step['transit_details']['arrival_time']['text'])
        print(step['transit_details']['line']['vehicle']['name'])
        transit_modes.append(step['transit_details']['line']['vehicle']['name'])
    else:
        print(step['duration']['value'])
        if step['duration']['value'] > 60:
            transit_modes.append(step['travel_mode'])
#     for item in step:
#         print(item)
    print('\n')
# Out:
# 5 mins
# 0.4 km
# {'lat': 52.3717958, 'lng': 4.965470499999999}
# {'lat': 52.3712922, 'lng': 4.9621277}
# WALKING
# 328
#
#
# 5 mins
# 2.3 km
# {'lat': 52.37129299999999, 'lng': 4.962181999999999}
# {'lat': 52.3615858, 'lng': 4.9389233}
# TRANSIT
# Amsterdam, Zuiderzeeweg
# 11:32am
# Amsterdam, Molukkenstraat
# 11:36am
# Bus
#
#
# 1 min
# 61 m
# {'lat': 52.3614679, 'lng': 4.938971599999999}
# {'lat': 52.3614741, 'lng': 4.9396397}
# WALKING
# 44
#
#
# 5 mins
# 2.0 km
# {'lat': 52.36153669999999, 'lng': 4.9391624}
# {'lat': 52.35433039999999, 'lng': 4.958298099999999}
# TRANSIT
# Amsterdam, Molukkenstraat
# 11:42am
# Science Park Terra
# 11:46am
# Bus
#
#
# 2 mins
# 0.2 km
# {'lat': 52.3543424, 'lng': 4.9582806}
# {'lat': 52.3535392, 'lng': 4.956428300000001}
# WALKING
# 114

# %%
transit_modes
# Out:
# ['WALKING', 'Bus', 'Bus', 'WALKING']

# %%
def get_transport_icons(route):
    transit_modes = []
    icons = []

    for step in route['steps']:
        if step['travel_mode'] == 'TRANSIT':
            transit_modes.append(step['transit_details']['line']['vehicle']['name'])
        else:
            if step['duration']['value'] > 60:
                transit_modes.append(step['travel_mode'])
                
    print(transit_modes)

    for mode in transit_modes:
        if mode == 'WALKING':
            icons.append('ph-person-simple-walk')
        elif mode == 'Bus':
            icons.append('ph-bus')
        elif mode == 'Train':
            icons.append('ph-train-regional')
        elif mode == 'Metro':
            icons.append('ph-train-simple')
        elif mode == 'Tram':
            icons.append('ph-train')
        else:
            icons.append('ph-question')

    return icons

# %%
def parse_json(json_resp):
    if json_resp['status'] == 'OK':
        all_journeys = []
        num_journeys = 0

        for i in range(len(json_resp['routes'])):
            route = json_resp['routes'][i]['legs'][0]
            if 'arrival_time' in route:
                num_journeys += 1
                walk_time = 0
                for step in route['steps']:
                    if step['travel_mode'] == 'WALKING':
                        walk_time += step['duration']['value']
                walk_time = round(walk_time / 60)

                ts_arr = int(route['arrival_time']['value'])
                arrival_time = datetime.datetime.utcfromtimestamp(ts_arr).strftime('%H:%M')
                ts_dep = int(route['departure_time']['value'])
                departure_time = datetime.datetime.utcfromtimestamp(ts_dep).strftime('%H:%M')
                # distance = route['distance']['text']
                duration = route['duration']['text']
                # start_address = route['start_address'].split(',')[0]
                # end_address = route['end_address'].split(',')[0]
                # end_location = route['end_location']
                icons = get_transport_icons(route)
                results = [departure_time, arrival_time, duration, walk_time, icons, len(icons)-1]
                all_journeys.append(results)
        all_journeys.append(num_journeys)

    else:
        all_journeys = ['No routes found']

    return all_journeys

# %%
parse_json(json_resp)
# Out:
# ['WALKING', 'Bus', 'Bus', 'WALKING']
# ['WALKING', 'Bus', 'WALKING']
# ['WALKING', 'Bus', 'Bus', 'WALKING']
# [['10:26',
#   '10:48',
#   '22 mins',
#   8,
#   ['ph-person-simple-walk', 'ph-bus', 'ph-bus', 'ph-person-simple-walk'],
#   3],
#  ['10:16',
#   '10:45',
#   '29 mins',
#   25,
#   ['ph-person-simple-walk', 'ph-bus', 'ph-person-simple-walk'],
#   2],
#  ['10:36',
#   '11:03',
#   '27 mins',
#   8,
#   ['ph-person-simple-walk', 'ph-bus', 'ph-bus', 'ph-person-simple-walk'],
#   3],
#  3]

# %%
route = json_resp['routes'][1]['legs'][0]
len(route['steps'])
# Out:
# 3

# %%
route['steps'][0]['travel_mode']
# Out:
# 'WALKING'

# %%
num_journeys = 0
for i in range(len(json_resp['routes'])):
    route = json_resp['routes'][i]['legs'][0]
    if 'arrival_time' in route:
        print('yes')
        num_journeys += 1
        
num_journeys
# Out:
# yes
# yes
# yes
# 3

# %%
walk_time = 0
for step in route['steps']:
    if step['travel_mode'] == 'WALKING':
        walk_time += step['duration']['value']

# %%
round(walk_time / 60)
# Out:
# 8
