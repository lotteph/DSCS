# %%
import requests
import json
import pandas as pd
import geocoder
from time import mktime
import datetime

# %% [markdown]
# # Darksky API
# 1000 calls per day
#
# https://darksky.net/dev/docs

# %%
DARKSKY_KEY = "d07fa9b030dfc7ae1a1897828f0e01de"

# %%
# Get current location in latitude and longitude

g = geocoder.ip('me')
print(g.latlng)
LAT = g.latlng[0]
LONG = g.latlng[1]
date = datetime.datetime.now()
# Out:
# [52.3666, 4.952]

# %%
def get_darksky_features(longitude, latitude, date):
    unix_date = mktime(date.timetuple())
    URL = "https://api.darksky.net/forecast/" + DARKSKY_KEY + "/" + str(latitude) + "," + str(longitude) + "," + str(int(unix_date)) +"?exclude=daily,alerts,flags&units=ca"
    r = requests.get(URL)
    json_str = r.content.decode("utf8").replace("'", '"')
    json_object = json.loads(json_str)
    return json_object

# %%
obj = get_darksky_features(LONG, LAT, date)

# %%
obj
# Out:
# {'latitude': 52.3666,
#  'longitude': 4.952,
#  'timezone': 'Europe/Amsterdam',
#  'currently': {'time': 1648116019,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 13.71,
#   'apparentTemperature': 13.71,
#   'dewPoint': 4.86,
#   'humidity': 0.55,
#   'pressure': 1030.7,
#   'windSpeed': 5.6,
#   'windGust': 7.75,
#   'windBearing': 26,
#   'cloudCover': 0.43,
#   'uvIndex': 2,
#   'visibility': 16.093,
#   'ozone': 349.9},
#  'hourly': {'summary': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1648076400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 8.74,
#     'apparentTemperature': 7.44,
#     'dewPoint': 5.02,
#     'humidity': 0.77,
#     'pressure': 1030.5,
#     'windSpeed': 8.49,
#     'windGust': 8.87,
#     'windBearing': 67,
#     'cloudCover': 0.01,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 346.4},
#    {'time': 1648080000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 8.19,
#     'apparentTemperature': 7.02,
#     'dewPoint': 4.4,
#     'humidity': 0.77,
#     'pressure': 1030.1,
#     'windSpeed': 7.46,
#     'windGust': 7.9,
#     'windBearing': 68,
#     'cloudCover': 0.02,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 345.9},
#    {'time': 1648083600,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 7.69,
#     'apparentTemperature': 6.69,
#     'dewPoint': 3.89,
#     'humidity': 0.77,
#     'pressure': 1030.1,
#     'windSpeed': 6.5,
#     'windGust': 6.93,
#     'windBearing': 68,
#     'cloudCover': 0.02,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 347.2},
#    {'time': 1648087200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 6.95,
#     'apparentTemperature': 6.25,
#     'dewPoint': 4.55,
#     'humidity': 0.85,
#     'pressure': 1029.9,
#     'windSpeed': 5.18,
#     'windGust': 6.52,
#     'windBearing': 54,
#     'cloudCover': 0.03,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 347.8},
#    {'time': 1648090800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 6.37,
#     'apparentTemperature': 6.37,
#     'dewPoint': 4.13,
#     'humidity': 0.86,
#     'pressure': 1029.7,
#     'windSpeed': 4.47,
#     'windGust': 6.31,
#     'windBearing': 49,
#     'cloudCover': 0.04,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 348},
#    {'time': 1648094400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 5.65,
#     'apparentTemperature': 5.65,
#     'dewPoint': 3.64,
#     'humidity': 0.87,
#     'pressure': 1029.5,
#     'windSpeed': 3.66,
#     'windGust': 5.23,
#     'windBearing': 48,
#     'cloudCover': 0.08,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 347.2},
#    {'time': 1648098000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 4.96,
#     'apparentTemperature': 4.96,
#     'dewPoint': 3.33,
#     'humidity': 0.89,
#     'pressure': 1029.7,
#     'windSpeed': 3.84,
#     'windGust': 5.27,
#     'windBearing': 43,
#     'cloudCover': 0.08,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 347.1},
#    {'time': 1648101600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 4.75,
#     'apparentTemperature': 4.75,
#     'dewPoint': 3,
#     'humidity': 0.88,
#     'pressure': 1030,
#     'windSpeed': 3.48,
#     'windGust': 4.62,
#     'windBearing': 27,
#     'cloudCover': 0.13,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 345.7},
#    {'time': 1648105200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 6.39,
#     'apparentTemperature': 6.39,
#     'dewPoint': 3.59,
#     'humidity': 0.82,
#     'pressure': 1030.3,
#     'windSpeed': 3.25,
#     'windGust': 4.64,
#     'windBearing': 22,
#     'cloudCover': 0.27,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 346.4},
#    {'time': 1648108800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 8.73,
#     'apparentTemperature': 8.73,
#     'dewPoint': 3.99,
#     'humidity': 0.72,
#     'pressure': 1030.4,
#     'windSpeed': 3.5,
#     'windGust': 5.9,
#     'windBearing': 22,
#     'cloudCover': 0.3,
#     'uvIndex': 1,
#     'visibility': 16.093,
#     'ozone': 346.9},
#    {'time': 1648112400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 11.43,
#     'apparentTemperature': 11.43,
#     'dewPoint': 4.64,
#     'humidity': 0.63,
#     'pressure': 1030.6,
#     'windSpeed': 4.34,
#     'windGust': 7.09,
#     'windBearing': 24,
#     'cloudCover': 0.35,
#     'uvIndex': 2,
#     'visibility': 16.093,
#     'ozone': 346.6},
#    {'time': 1648116000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 13.7,
#     'apparentTemperature': 13.7,
#     'dewPoint': 4.86,
#     'humidity': 0.55,
#     'pressure': 1030.7,
#     'windSpeed': 5.59,
#     'windGust': 7.75,
#     'windBearing': 26,
#     'cloudCover': 0.43,
#     'uvIndex': 2,
#     'visibility': 16.093,
#     'ozone': 349.9},
#    {'time': 1648119600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 15.29,
#     'apparentTemperature': 15.29,
#     'dewPoint': 4.6,
#     'humidity': 0.49,
#     'pressure': 1030.5,
#     'windSpeed': 6.97,
#     'windGust': 7.55,
#     'windBearing': 30,
#     'cloudCover': 0.43,
#     'uvIndex': 3,
#     'visibility': 16.093,
#     'ozone': 353.8},
#    {'time': 1648123200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 16.76,
#     'apparentTemperature': 16.76,
#     'dewPoint': 4.72,
#     'humidity': 0.45,
#     'pressure': 1030.3,
#     'windSpeed': 7.84,
#     'windGust': 7.84,
#     'windBearing': 36,
#     'cloudCover': 0.42,
#     'uvIndex': 3,
#     'visibility': 16.093,
#     'ozone': 352.6},
#    {'time': 1648126800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 17.58,
#     'apparentTemperature': 17.58,
#     'dewPoint': 4.44,
#     'humidity': 0.42,
#     'pressure': 1030,
#     'windSpeed': 9.03,
#     'windGust': 9.03,
#     'windBearing': 36,
#     'cloudCover': 0.39,
#     'uvIndex': 3,
#     'visibility': 16.093,
#     'ozone': 353.4},
#    {'time': 1648130400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 17.92,
#     'apparentTemperature': 17.92,
#     'dewPoint': 4.39,
#     'humidity': 0.41,
#     'pressure': 1029.4,
#     'windSpeed': 10.21,
#     'windGust': 10.21,
#     'windBearing': 33,
#     'cloudCover': 0.35,
#     'uvIndex': 2,
#     'visibility': 16.093,
#     'ozone': 353.8},
#    {'time': 1648134000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 17.54,
#     'apparentTemperature': 17.54,
#     'dewPoint': 4.48,
#     'humidity': 0.42,
#     'pressure': 1029.1,
#     'windSpeed': 11.26,
#     'windGust': 11.26,
#     'windBearing': 29,
#     'cloudCover': 0.39,
#     'uvIndex': 1,
#     'visibility': 16.093,
#     'ozone': 355.2},
#    {'time': 1648137600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 16.51,
#     'apparentTemperature': 16.51,
#     'dewPoint': 4.7,
#     'humidity': 0.46,
#     'pressure': 1028.8,
#     'windSpeed': 11.63,
#     'windGust': 12.24,
#     'windBearing': 25,
#     'cloudCover': 0.31,
#     'uvIndex': 1,
#     'visibility': 16.093,
#     'ozone': 355.8},
#    {'time': 1648141200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 14.72,
#     'apparentTemperature': 14.72,
#     'dewPoint': 4.53,
#     'humidity': 0.5,
#     'pressure': 1028.9,
#     'windSpeed': 11.6,
#     'windGust': 17.44,
#     'windBearing': 21,
#     'cloudCover': 0.27,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 353.8},
#    {'time': 1648144800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 12.76,
#     'apparentTemperature': 12.76,
#     'dewPoint': 3.81,
#     'humidity': 0.54,
#     'pressure': 1029.3,
#     'windSpeed': 11.3,
#     'windGust': 19.08,
#     'windBearing': 19,
#     'cloudCover': 0.38,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 352.4},
#    {'time': 1648148400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 11.21,
#     'apparentTemperature': 11.21,
#     'dewPoint': 3.6,
#     'humidity': 0.59,
#     'pressure': 1029.6,
#     'windSpeed': 10.87,
#     'windGust': 18.65,
#     'windBearing': 22,
#     'cloudCover': 0.46,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 350.1},
#    {'time': 1648152000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 9.91,
#     'apparentTemperature': 8.5,
#     'dewPoint': 3.55,
#     'humidity': 0.65,
#     'pressure': 1030,
#     'windSpeed': 10.2,
#     'windGust': 17.34,
#     'windBearing': 22,
#     'cloudCover': 0.46,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 348.1},
#    {'time': 1648155600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 8.94,
#     'apparentTemperature': 7.45,
#     'dewPoint': 3.74,
#     'humidity': 0.7,
#     'pressure': 1030.3,
#     'windSpeed': 9.57,
#     'windGust': 15.4,
#     'windBearing': 24,
#     'cloudCover': 0.4,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 344.1},
#    {'time': 1648159200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 8.22,
#     'apparentTemperature': 6.77,
#     'dewPoint': 3.98,
#     'humidity': 0.75,
#     'pressure': 1030.4,
#     'windSpeed': 8.77,
#     'windGust': 12.37,
#     'windBearing': 29,
#     'cloudCover': 0.33,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 340.9}]},
#  'offset': 1}

# %% [markdown]
# # NS API
# 1000 calls per 5 minutes (I think)
#
# Probably not going to use this API since we have the Google Directions API

# %%
# NS_REIS_KEY = "e6a58e80f2b444efbc97fc302485c199"

# %%
# # Code from https://apiportal.ns.nl/docs/services/reisinformatie-api/operations/getStations?
# import http.client, urllib.request, urllib.parse, urllib.error, base64

# headers = {
#     # Request headers
#     'Ocp-Apim-Subscription-Key': NS_REIS_KEY,
# }

# params = urllib.parse.urlencode({
# })

# try:
#     conn = http.client.HTTPSConnection('gateway.apiportal.ns.nl')
#     conn.request("GET", "/reisinformatie-api/api/v2/stations?%s" % params, "{body}", headers)
#     response = conn.getresponse()
#     data = response.read()
#     print(data)
#     conn.close()
# except Exception as e:
#     print("[Errno {0}] {1}".format(e.errno, e.strerror))

# %%
# import http.client, urllib.request, urllib.parse, urllib.error, base64

# headers = {
#     # Request headers
#     'Authorization': '',
#     'Ocp-Apim-Subscription-Key': NS_REIS_KEY,
# }

# params = urllib.parse.urlencode({
#     # Request parameters
#     'originLat': 52.371269,
#     'originLng': 4.966500,
#     'destinationLat': 52.374,
#     'destinationLng': 4.8897,
# })

# try:
#     conn = http.client.HTTPSConnection('gateway.apiportal.ns.nl')
#     conn.request("GET", "/reisinformatie-api/api/v3/trips?%s" % params, "{body}", headers)
#     response = conn.getresponse()
#     data = response.read()
#     print(data)
#     conn.close()
# except Exception as e:
#     print("[Errno {0}] {1}".format(e.errno, e.strerror))

# %% [markdown]
# # Google Maps API

# %%
GOOGLE_MAPS_KEY = "AIzaSyAJiy_cEFCxdnBHlWCvnnlVBj6zcTfZfSk"
ORIG = "Marie Baronlaan 19"
DEST = "Science Park 904"
date = datetime.datetime.now()
TIME = mktime(date.timetuple())
TIME = str(int(1647943620))

# %%
url = "https://maps.googleapis.com/maps/api/directions/json?origin=" + ORIG + "&destination=" + DEST + "&mode=transit&departure_time=" + TIME + "&key=" + GOOGLE_MAPS_KEY + "&alternatives=true"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "geocoded_waypoints" : [
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJleI-4zIJxkcRyRzyLQIMhh8",
#          "types" : [ "street_address" ]
#       },
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJOyED378JxkcRn0ZjHtBXZtc",
#          "types" : [ "street_address" ]
#       }
#    ],
#    "routes" : [
#       {
#          "bounds" : {
#             "northeast" : {
#                "lat" : 52.37229689999999,
#                "lng" : 4.973016100000001
#             },
#             "southwest" : {
#                "lat" : 52.3522513,
#                "lng" : 4.9389157
#             }
#          },
#          "copyrights" : "Map data ©2022",
#          "legs" : [
#             {
#                "arrival_time" : {
#                   "text" : "11:48am",
#                   "time_zone" : "Europe/Amsterdam",
#                   "value" : 1647946116
#                },
#                "departure_time" : {
#                   "text" : "11:17am",
#                   "time_zone" : "Europe/Amsterdam",
#                   "value" : 1647944258
#                },
#                "distance" : {
#                   "text" : "5.6 km",
#                   "value" : 5618
#                },
#                "duration" : {
#                   "text" : "31 mins",
#                   "value" : 1858
#                },
#                "end_address" : "Science Park 904, 1098 XH Amsterdam, Netherlands",
#                "end_location" : {
#                   "lat" : 52.3535392,
#                   "lng" : 4.956428300000001
#                },
#                "start_address" : "Marie Baronlaan 19, 1095 KG Amsterdam, Netherlands",
#                "start_location" : {
#                   "lat" : 52.3716209,
#                   "lng" : 4.972947
#                },
#                "steps" : [
#                   {
#                      "distance" : {
#                         "text" : "1.1 km",
#                         "value" : 1135
#                      },
#                      "duration" : {
#                         "text" : "14 mins",
#                         "value" : 862
#                      },
#                      "end_location" : {
#                         "lat" : 52.3712922,
#                         "lng" : 4.9621277
#                      },
#                      "html_instructions" : "Walk to Amsterdam, Zuiderzeeweg",
#                      "polyline" : {
#                         "points" : "sys~H}gj]QEGCEACAA??@A?A??@INIVIPDFpArBb@p@JPu@hBMZCFHNDDJNRZp@fAdAbBJN~BrD~@tAYp@y@jB[t@OZqBvEe@fAc@dAO^Qd@Wr@YbAUz@CLADMn@Ox@CHG^OfAGh@EVP@@?F?R?P@T?`@?CXACAVANCVETbBC"
#                      },
#                      "start_location" : {
#                         "lat" : 52.3716209,
#                         "lng" : 4.972947
#                      },
#                      "steps" : [
#                         {
#                            "distance" : {
#                               "text" : "47 m",
#                               "value" : 47
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 34
#                            },
#                            "end_location" : {
#                               "lat" : 52.3719775,
#                               "lng" : 4.9727105
#                            },
#                            "html_instructions" : "Head \u003cb\u003enorth\u003c/b\u003e on \u003cb\u003eMarie Baronlaan\u003c/b\u003e",
#                            "polyline" : {
#                               "points" : "sys~H}gj]QEGCEACAA??@A?A??@INIVIP"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3716209,
#                               "lng" : 4.972947
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "0.1 km",
#                               "value" : 108
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 81
#                            },
#                            "end_location" : {
#                               "lat" : 52.3712988,
#                               "lng" : 4.971747
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e to stay on \u003cb\u003eMarie Baronlaan\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "{{s~Hmfj]DFpArBb@p@JP"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3719775,
#                               "lng" : 4.9727105
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "63 m",
#                               "value" : 63
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 45
#                            },
#                            "end_location" : {
#                               "lat" : 52.3716054,
#                               "lng" : 4.970960499999999
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e onto \u003cb\u003eFaas Wilkesstraat\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "sws~Hm`j]u@hBMZCFHN"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3712988,
#                               "lng" : 4.971747
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "0.3 km",
#                               "value" : 268
#                            },
#                            "duration" : {
#                               "text" : "3 mins",
#                               "value" : 194
#                            },
#                            "end_location" : {
#                               "lat" : 52.3698045,
#                               "lng" : 4.9684354
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003eBob Haarmslaan\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "qys~Ho{i]DDJNRZp@fAdAbBJN~BrD~@tA"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3716054,
#                               "lng" : 4.970960499999999
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "0.5 km",
#                               "value" : 488
#                            },
#                            "duration" : {
#                               "text" : "6 mins",
#                               "value" : 352
#                            },
#                            "end_location" : {
#                               "lat" : 52.37229689999999,
#                               "lng" : 4.9626652
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "gns~Hwki]Yp@y@jB[t@OZqBvEe@fAc@dAO^Qd@Wr@YbAUz@CLADMn@Ox@CHG^OfAGh@EV"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3698045,
#                               "lng" : 4.9684354
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "68 m",
#                               "value" : 68
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 69
#                            },
#                            "end_location" : {
#                               "lat" : 52.3716872,
#                               "lng" : 4.9626458
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "{}s~Hugh]P@@?F?R?P@T?`@?"
#                            },
#                            "start_location" : {
#                               "lat" : 52.37229689999999,
#                               "lng" : 4.9626652
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "38 m",
#                               "value" : 38
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 47
#                            },
#                            "end_location" : {
#                               "lat" : 52.3717885,
#                               "lng" : 4.962108499999999
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "azs~Hqgh]CXACAVANCVET"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3716872,
#                               "lng" : 4.9626458
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "55 m",
#                               "value" : 55
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 40
#                            },
#                            "end_location" : {
#                               "lat" : 52.3712922,
#                               "lng" : 4.9621277
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e\u003cdiv style=\"font-size:0.9em\"\u003eDestination will be on the left\u003c/div\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "uzs~Hedh]bBC"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3717885,
#                               "lng" : 4.962108499999999
#                            },
#                            "travel_mode" : "WALKING"
#                         }
#                      ],
#                      "travel_mode" : "WALKING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "2.3 km",
#                         "value" : 2293
#                      },
#                      "duration" : {
#                         "text" : "5 mins",
#                         "value" : 289
#                      },
#                      "end_location" : {
#                         "lat" : 52.3615858,
#                         "lng" : 4.9389233
#                      },
#                      "html_instructions" : "Bus towards Amstelstation",
#                      "polyline" : {
#                         "points" : "qws~Hsdh]?UV@PAl@AF?p@DD@D@B?D?F?HAHAJAHAHAF?RAn@CB?JCfDC@?X?N@^?J@L@H?F@HBNBVFZJPFJDPJZRJHJFJJRPRTDDFFFHLRPXJRJPDNLVN`@Pf@Nd@Lh@FZDPBPBP@@Db@Hp@Dl@Df@Bt@Bb@?BB\\?D?D@H@RHzBJzB@`@@RDt@?B?NBn@Bl@NjDHvBThFBx@Bb@@T?F@Z@ZBh@@f@@h@@B@n@@x@@t@?J?DAZ?N?X?\\?h@?b@?@Ab@AVAT?X?RBZFrADPFRJXFNBJDJFJFHHJFLHHFDDBDBFBHFNFp@Pn@RHB`@LTFXHr@Rf@Nr@LLFHFHJFFBFFJDJDPBL?FBNDh@Dh@HtAJrA\\dEFt@@NJvA^tFBd@FbAFt@Bf@Dr@BZHrA@VHdA@H@JB^@LDf@Dl@B?"
#                      },
#                      "start_location" : {
#                         "lat" : 52.37129299999999,
#                         "lng" : 4.962181999999999
#                      },
#                      "transit_details" : {
#                         "arrival_stop" : {
#                            "location" : {
#                               "lat" : 52.3615858,
#                               "lng" : 4.9389233
#                            },
#                            "name" : "Amsterdam, Molukkenstraat"
#                         },
#                         "arrival_time" : {
#                            "text" : "11:36am",
#                            "time_zone" : "Europe/Amsterdam",
#                            "value" : 1647945409
#                         },
#                         "departure_stop" : {
#                            "location" : {
#                               "lat" : 52.37129299999999,
#                               "lng" : 4.962181999999999
#                            },
#                            "name" : "Amsterdam, Zuiderzeeweg"
#                         },
#                         "departure_time" : {
#                            "text" : "11:32am",
#                            "time_zone" : "Europe/Amsterdam",
#                            "value" : 1647945120
#                         },
#                         "headsign" : "Amstelstation",
#                         "line" : {
#                            "agencies" : [
#                               {
#                                  "name" : "GVB",
#                                  "phone" : "011 31 900 8011",
#                                  "url" : "http://www.gvb.nl/"
#                               }
#                            ],
#                            "name" : "Station Noord - Amstelstation",
#                            "short_name" : "37",
#                            "url" : "http://www.gvb.nl/lijn/bus/37",
#                            "vehicle" : {
#                               "icon" : "//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png",
#                               "name" : "Bus",
#                               "type" : "BUS"
#                            }
#                         },
#                         "num_stops" : 3
#                      },
#                      "travel_mode" : "TRANSIT"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "61 m",
#                         "value" : 61
#                      },
#                      "duration" : {
#                         "text" : "1 min",
#                         "value" : 44
#                      },
#                      "end_location" : {
#                         "lat" : 52.3614741,
#                         "lng" : 4.9396397
#                      },
#                      "html_instructions" : "Walk to Amsterdam, Molukkenstraat",
#                      "polyline" : {
#                         "points" : "ezq~Hqsc]P?ImAGu@?A"
#                      },
#                      "start_location" : {
#                         "lat" : 52.3614679,
#                         "lng" : 4.938971599999999
#                      },
#                      "steps" : [
#                         {
#                            "distance" : {
#                               "text" : "61 m",
#                               "value" : 61
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 44
#                            },
#                            "end_location" : {
#                               "lat" : 52.3614741,
#                               "lng" : 4.9396397
#                            },
#                            "html_instructions" : "Head \u003cb\u003eeast\u003c/b\u003e on \u003cb\u003eInsulindeweg\u003c/b\u003e toward \u003cb\u003eMolukkenstraat\u003c/b\u003e\u003cdiv style=\"font-size:0.9em\"\u003eDestination will be on the right\u003c/div\u003e",
#                            "polyline" : {
#                               "points" : "ezq~Hqsc]P?ImAGu@?A"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3614679,
#                               "lng" : 4.938971599999999
#                            },
#                            "travel_mode" : "WALKING"
#                         }
#                      ],
#                      "travel_mode" : "WALKING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "2.0 km",
#                         "value" : 1973
#                      },
#                      "duration" : {
#                         "text" : "5 mins",
#                         "value" : 281
#                      },
#                      "end_location" : {
#                         "lat" : 52.35433039999999,
#                         "lng" : 4.958298099999999
#                      },
#                      "html_instructions" : "Bus towards Amstelstation",
#                      "polyline" : {
#                         "points" : "szq~Hwtc]FAC]Gu@E_@ZO^ITIb@MZIn@ObAYl@Od@Ex@U`AWXOFEb@M@AH@D?D?JCDAJ?\\Kz@SH?H?PCAQ?w@@Q?G?G@I@]NsBPgCVcDHaA?A@O?SBgA?G@i@@g@?U@U?]@K@M@E@OBKBI?AFSBE@GFKFOFMBEBGZm@P_@Xg@dDmGbAiBJMrC_FHQ`@}@n@iAd@}@LSVc@xBiEn@qALS\\q@b@}@Vi@Zq@Ra@NYPYHYMUGMCEGECEEGEGCEGKUg@OY]q@IOc@{@GKCIEKGKEKGSUm@AEAAAAGGSi@Ma@CGEMEIAEISc@gAYo@]w@O]DI"
#                      },
#                      "start_location" : {
#                         "lat" : 52.36153669999999,
#                         "lng" : 4.9391624
#                      },
#                      "transit_details" : {
#                         "arrival_stop" : {
#                            "location" : {
#                               "lat" : 52.35433039999999,
#                               "lng" : 4.958298099999999
#                            },
#                            "name" : "Science Park Terra"
#                         },
#                         "arrival_time" : {
#                            "text" : "11:46am",
#                            "time_zone" : "Europe/Amsterdam",
#                            "value" : 1647946002
#                         },
#                         "departure_stop" : {
#                            "location" : {
#                               "lat" : 52.36153669999999,
#                               "lng" : 4.9391624
#                            },
#                            "name" : "Amsterdam, Molukkenstraat"
#                         },
#                         "departure_time" : {
#                            "text" : "11:42am",
#                            "time_zone" : "Europe/Amsterdam",
#                            "value" : 1647945721
#                         },
#                         "headsign" : "Amstelstation",
#                         "line" : {
#                            "agencies" : [
#                               {
#                                  "name" : "GVB",
#                                  "phone" : "011 31 900 8011",
#                                  "url" : "http://www.gvb.nl/"
#                               }
#                            ],
#                            "name" : "Amstelstation - Muiderpoortstation",
#                            "short_name" : "40",
#                            "url" : "http://www.gvb.nl/lijn/bus/40",
#                            "vehicle" : {
#                               "icon" : "//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png",
#                               "name" : "Bus",
#                               "type" : "BUS"
#                            }
#                         },
#                         "num_stops" : 4
#                      },
#                      "travel_mode" : "TRANSIT"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "0.2 km",
#                         "value" : 156
#                      },
#                      "duration" : {
#                         "text" : "2 mins",
#                         "value" : 114
#                      },
#                      "end_location" : {
#                         "lat" : 52.3535392,
#                         "lng" : 4.956428300000001
#                      },
#                      "html_instructions" : "Walk to Science Park 904, 1098 XH Amsterdam, Netherlands",
#                      "polyline" : {
#                         "points" : "smp~Hglg]N\\Xl@KNBJRf@LPZx@HR@DFNFPL`@Rf@?F@F"
#                      },
#                      "start_location" : {
#                         "lat" : 52.3543424,
#                         "lng" : 4.9582806
#                      },
#                      "steps" : [
#                         {
#                            "distance" : {
#                               "text" : "0.1 km",
#                               "value" : 149
#                            },
#                            "duration" : {
#                               "text" : "2 mins",
#                               "value" : 109
#                            },
#                            "end_location" : {
#                               "lat" : 52.3535522,
#                               "lng" : 4.9565101
#                            },
#                            "html_instructions" : "Head \u003cb\u003esouthwest\u003c/b\u003e",
#                            "polyline" : {
#                               "points" : "smp~Hglg]N\\Xl@KNBJRf@LPZx@HR@DFNFPL`@Rf@"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3543424,
#                               "lng" : 4.9582806
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "7 m",
#                               "value" : 7
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 5
#                            },
#                            "end_location" : {
#                               "lat" : 52.3535392,
#                               "lng" : 4.956428300000001
#                            },
#                            "html_instructions" : "Slight \u003cb\u003eright\u003c/b\u003e\u003cdiv style=\"font-size:0.9em\"\u003eDestination will be on the right\u003c/div\u003e",
#                            "maneuver" : "turn-slight-right",
#                            "polyline" : {
#                               "points" : "uhp~Heag]?F@F"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3535522,
#                               "lng" : 4.9565101
#                            },
#                            "travel_mode" : "WALKING"
#                         }
#                      ],
#                      "travel_mode" : "WALKING"
#                   }
#                ],
#                "traffic_speed_entry" : [],
#                "via_waypoint" : []
#             }
#          ],
#          "overview_polyline" : {
#             "points" : "sys~H}gj]c@ME@]z@fC~DcAdCCFHNPTdAbBpG|J_CnFkEdKi@xAo@~Bc@|Bc@zCEVP@H?|A@CXACCf@Il@bBC?I?UV@~@CdAHP?h@GtAGNChDCtABh@FtA^dAn@~@z@b@j@n@nA\\x@`@lA^hBThBV|E\\jI|@tTRdGH~ECvECzAJnBLd@\\`A`@n@VRVN`GdBzA\\VN\\f@Nr@XxDr@~Iv@vLl@hJL`BDl@B?VIP?QcCM|AFAC]MuAtBq@|DcAd@Ex@U`AWXOj@SJ?VCPAxA_@R?PCAQ@iA?Od@cHb@wFH_GFo@Nk@d@eAlFcKlFiJpAgCr@qAnEsItBkEb@{@Zs@a@o@S[eCaFw@oBGGSi@Qi@Wq@kBmEDIABh@jAKNBJ`@x@n@bBh@bB@F"
#          },
#          "summary" : "",
#          "warnings" : [
#             "Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths."
#          ],
#          "waypoint_order" : []
#       },
#       {
#          "bounds" : {
#             "northeast" : {
#                "lat" : 52.3736439,
#                "lng" : 4.973016100000001
#             },
#             "southwest" : {
#                "lat" : 52.3522513,
#                "lng" : 4.9340088
#             }
#          },
#          "copyrights" : "Map data ©2022",
#          "legs" : [
#             {
#                "arrival_time" : {
#                   "text" : "11:48am",
#                   "time_zone" : "Europe/Amsterdam",
#                   "value" : 1647946116
#                },
#                "departure_time" : {
#                   "text" : "11:09am",
#                   "time_zone" : "Europe/Amsterdam",
#                   "value" : 1647943740
#                },
#                "distance" : {
#                   "text" : "7.0 km",
#                   "value" : 6972
#                },
#                "duration" : {
#                   "text" : "40 mins",
#                   "value" : 2376
#                },
#                "end_address" : "Science Park 904, 1098 XH Amsterdam, Netherlands",
#                "end_location" : {
#                   "lat" : 52.3535392,
#                   "lng" : 4.956428300000001
#                },
#                "start_address" : "Marie Baronlaan 19, 1095 KG Amsterdam, Netherlands",
#                "start_location" : {
#                   "lat" : 52.3716209,
#                   "lng" : 4.972947
#                },
#                "steps" : [
#                   {
#                      "distance" : {
#                         "text" : "0.6 km",
#                         "value" : 554
#                      },
#                      "duration" : {
#                         "text" : "7 mins",
#                         "value" : 423
#                      },
#                      "end_location" : {
#                         "lat" : 52.3692943,
#                         "lng" : 4.968629
#                      },
#                      "html_instructions" : "Walk to Amsterdam, Bob Haarmslaan",
#                      "polyline" : {
#                         "points" : "sys~H}gj]QEGCEACAA??@A?A??@INIVIPDFpArBb@p@JPJNw@hBGPBDLNRZp@fAdAbBJN|BrD~@tAJLLPHHJPl@oA"
#                      },
#                      "start_location" : {
#                         "lat" : 52.3716209,
#                         "lng" : 4.972947
#                      },
#                      "steps" : [
#                         {
#                            "distance" : {
#                               "text" : "47 m",
#                               "value" : 47
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 34
#                            },
#                            "end_location" : {
#                               "lat" : 52.3719775,
#                               "lng" : 4.9727105
#                            },
#                            "html_instructions" : "Head \u003cb\u003enorth\u003c/b\u003e on \u003cb\u003eMarie Baronlaan\u003c/b\u003e",
#                            "polyline" : {
#                               "points" : "sys~H}gj]QEGCEACAA??@A?A??@INIVIP"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3716209,
#                               "lng" : 4.972947
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "0.1 km",
#                               "value" : 108
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 81
#                            },
#                            "end_location" : {
#                               "lat" : 52.3712439,
#                               "lng" : 4.9716708
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e to stay on \u003cb\u003eMarie Baronlaan\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "{{s~Hmfj]DFpArBb@p@JPJN"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3719775,
#                               "lng" : 4.9727105
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "63 m",
#                               "value" : 63
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 47
#                            },
#                            "end_location" : {
#                               "lat" : 52.3715598,
#                               "lng" : 4.9710516
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e onto \u003cb\u003eFaas Wilkesstraat\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "gws~H}_j]w@hBGP"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3712439,
#                               "lng" : 4.9716708
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "0.3 km",
#                               "value" : 296
#                            },
#                            "duration" : {
#                               "text" : "4 mins",
#                               "value" : 223
#                            },
#                            "end_location" : {
#                               "lat" : 52.369515,
#                               "lng" : 4.9682263
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003eBob Haarmslaan\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "gys~Ha|i]BDLNRZp@fAdAbBJN|BrD~@tAJLLPHHJP"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3715598,
#                               "lng" : 4.9710516
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "40 m",
#                               "value" : 40
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 38
#                            },
#                            "end_location" : {
#                               "lat" : 52.3692943,
#                               "lng" : 4.968629
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003eIJburglaan\u003c/b\u003e/\u003cwbr/\u003e\u003cb\u003es114\u003c/b\u003e\u003cdiv style=\"font-size:0.9em\"\u003eDestination will be on the right\u003c/div\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "ols~Hmji]l@oA"
#                            },
#                            "start_location" : {
#                               "lat" : 52.369515,
#                               "lng" : 4.9682263
#                            },
#                            "travel_mode" : "WALKING"
#                         }
#                      ],
#                      "travel_mode" : "WALKING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "2.5 km",
#                         "value" : 2521
#                      },
#                      "duration" : {
#                         "text" : "3 mins",
#                         "value" : 197
#                      },
#                      "end_location" : {
#                         "lat" : 52.3730951,
#                         "lng" : 4.9340664
#                      },
#                      "html_instructions" : "Tram towards Centraal Station",
#                      "polyline" : {
#                         "points" : "ujs~Hmli]DHoKpVUz@Qt@Mj@Kn@[zBE\\CFEv@EXAHG\\Gf@]tA?@Ip@CH_BnKUhBc@vCIf@Id@Gl@e@~DOzBEp@Gx@ANIvC?tD@|@@x@Bz@@z@PvDFtA@F?Hn@tKfAvP?BfA|Pf@`LPdEAxBCxAAv@At@YlEW|COjAAJKt@EVSrAKh@Mj@Of@Sv@]hAETMK"
#                      },
#                      "start_location" : {
#                         "lat" : 52.3692335,
#                         "lng" : 4.9685451
#                      },
#                      "transit_details" : {
#                         "arrival_stop" : {
#                            "location" : {
#                               "lat" : 52.3730951,
#                               "lng" : 4.9340664
#                            },
#                            "name" : "Amsterdam, Rietlandpark"
#                         },
#                         "arrival_time" : {
#                            "text" : "11:20am",
#                            "time_zone" : "Europe/Amsterdam",
#                            "value" : 1647944417
#                         },
#                         "departure_stop" : {
#                            "location" : {
#                               "lat" : 52.3692335,
#                               "lng" : 4.9685451
#                            },
#                            "name" : "Amsterdam, Bob Haarmslaan"
#                         },
#                         "departure_time" : {
#                            "text" : "11:17am",
#                            "time_zone" : "Europe/Amsterdam",
#                            "value" : 1647944220
#                         },
#                         "headsign" : "Centraal Station",
#                         "line" : {
#                            "agencies" : [
#                               {
#                                  "name" : "GVB",
#                                  "phone" : "011 31 900 8011",
#                                  "url" : "http://www.gvb.nl/"
#                               }
#                            ],
#                            "name" : "IJburg - Centraal Station",
#                            "short_name" : "26",
#                            "url" : "http://www.gvb.nl/lijn/tram/26",
#                            "vehicle" : {
#                               "icon" : "//maps.gstatic.com/mapfiles/transit/iw2/6/tram2.png",
#                               "name" : "Tram",
#                               "type" : "TRAM"
#                            }
#                         },
#                         "num_stops" : 2
#                      },
#                      "travel_mode" : "TRANSIT"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "0.4 km",
#                         "value" : 355
#                      },
#                      "duration" : {
#                         "text" : "4 mins",
#                         "value" : 269
#                      },
#                      "end_location" : {
#                         "lat" : 52.3735681,
#                         "lng" : 4.9387367
#                      },
#                      "html_instructions" : "Walk to Amsterdam, C. van Eesterenlaan",
#                      "polyline" : {
#                         "points" : "_ct~H{tb]DSJa@BCFAD@_@mBROIq@AMGa@?ICW?GEq@Eo@?KCc@AWEy@Gy@Ey@Ey@Ey@Em@AK?GOAE?@OCUCMC_@"
#                      },
#                      "start_location" : {
#                         "lat" : 52.3731219,
#                         "lng" : 4.9340629
#                      },
#                      "steps" : [
#                         {
#                            "distance" : {
#                               "text" : "32 m",
#                               "value" : 32
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 33
#                            },
#                            "end_location" : {
#                               "lat" : 52.372939,
#                               "lng" : 4.934347499999999
#                            },
#                            "html_instructions" : "Head \u003cb\u003esoutheast\u003c/b\u003e toward \u003cb\u003eFred Petterbaan\u003c/b\u003e\u003cdiv style=\"font-size:0.9em\"\u003eTake the stairs\u003c/div\u003e",
#                            "polyline" : {
#                               "points" : "_ct~H{tb]DSJa@BCFAD@"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3731219,
#                               "lng" : 4.9340629
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "42 m",
#                               "value" : 42
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 31
#                            },
#                            "end_location" : {
#                               "lat" : 52.3730967,
#                               "lng" : 4.9349047
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003eFred Petterbaan\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "{at~Huvb]_@mB"
#                            },
#                            "start_location" : {
#                               "lat" : 52.372939,
#                               "lng" : 4.934347499999999
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "12 m",
#                               "value" : 12
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 9
#                            },
#                            "end_location" : {
#                               "lat" : 52.3729992,
#                               "lng" : 4.9349807
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e onto \u003cb\u003eFred Petterbaan\u003c/b\u003e/\u003cwbr/\u003e\u003cb\u003eRietlandpark\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "{bt~Hczb]RO"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3730967,
#                               "lng" : 4.9349047
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "0.2 km",
#                               "value" : 233
#                            },
#                            "duration" : {
#                               "text" : "3 mins",
#                               "value" : 166
#                            },
#                            "end_location" : {
#                               "lat" : 52.3734139,
#                               "lng" : 4.938310899999999
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e to stay on \u003cb\u003eFred Petterbaan\u003c/b\u003e/\u003cwbr/\u003e\u003cb\u003eRietlandpark\u003c/b\u003e\u003cdiv style=\"font-size:0.9em\"\u003eContinue to follow Fred Petterbaan\u003c/div\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "gbt~Hszb]Iq@AMGa@?ICW?GEq@Eo@?KCc@AWEy@Gy@Ey@Ey@Ey@Em@AK?G"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3729992,
#                               "lng" : 4.9349807
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "9 m",
#                               "value" : 9
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 6
#                            },
#                            "end_location" : {
#                               "lat" : 52.3735125,
#                               "lng" : 4.9383954
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003eC. van Eesterenlaan\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "ydt~Hmoc]OAE?@O"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3734139,
#                               "lng" : 4.938310899999999
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "27 m",
#                               "value" : 27
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 24
#                            },
#                            "end_location" : {
#                               "lat" : 52.3735681,
#                               "lng" : 4.9387367
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e onto \u003cb\u003eJ.F. Van Hengelstraat\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "met~H_pc]CUCMC_@"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3735125,
#                               "lng" : 4.9383954
#                            },
#                            "travel_mode" : "WALKING"
#                         }
#                      ],
#                      "travel_mode" : "WALKING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "1.8 km",
#                         "value" : 1769
#                      },
#                      "duration" : {
#                         "text" : "5 mins",
#                         "value" : 299
#                      },
#                      "end_location" : {
#                         "lat" : 52.358838,
#                         "lng" : 4.940735999999999
#                      },
#                      "html_instructions" : "Bus towards Station Zuid",
#                      "polyline" : {
#                         "points" : "cft~H_tc]C@?JBf@@T@VBb@H?F@N@hABl@?RAh@?f@?R?F?T?D?F?rACl@?d@AjAA@?dA?J?H?DAD?B?HAJCHAHA@AB?D?D?F?D?D?H@H@J@H?B@D?D?D?N@x@Ad@?JAP?TAR??U?WA}A?[@K?C?A@E?C@CBABCB?DAD?F?D?f@?b@?N?B?F?FAT?F?`@?VAP?P?P?N?PAN?B@V?B?D?b@?N?p@?f@?f@?@?VAX?X?P?t@AV?`AAhAAb@?h@?l@Av@CR?r@Ar@?j@?R?XAL?FAF@B?DADCHADCFCXGXKZO^ITIb@MZIn@ObAYl@Od@Ex@U`AWXOFEb@M@AH@AF"
#                      },
#                      "start_location" : {
#                         "lat" : 52.37361689999999,
#                         "lng" : 4.9390394
#                      },
#                      "transit_details" : {
#                         "arrival_stop" : {
#                            "location" : {
#                               "lat" : 52.358838,
#                               "lng" : 4.940735999999999
#                            },
#                            "name" : "Amsterdam, Valentijnkade"
#                         },
#                         "arrival_time" : {
#                            "text" : "11:34am",
#                            "time_zone" : "Europe/Amsterdam",
#                            "value" : 1647945264
#                         },
#                         "departure_stop" : {
#                            "location" : {
#                               "lat" : 52.37361689999999,
#                               "lng" : 4.9390394
#                            },
#                            "name" : "Amsterdam, C. van Eesterenlaan"
#                         },
#                         "departure_time" : {
#                            "text" : "11:29am",
#                            "time_zone" : "Europe/Amsterdam",
#                            "value" : 1647944965
#                         },
#                         "headsign" : "Station Zuid",
#                         "line" : {
#                            "agencies" : [
#                               {
#                                  "name" : "GVB",
#                                  "phone" : "011 31 900 8011",
#                                  "url" : "http://www.gvb.nl/"
#                               }
#                            ],
#                            "name" : "KNSM Eiland - Station Zuid",
#                            "short_name" : "65",
#                            "url" : "http://www.gvb.nl/lijn/bus/65",
#                            "vehicle" : {
#                               "icon" : "//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png",
#                               "name" : "Bus",
#                               "type" : "BUS"
#                            }
#                         },
#                         "num_stops" : 5
#                      },
#                      "travel_mode" : "TRANSIT"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "1.6 km",
#                         "value" : 1617
#                      },
#                      "duration" : {
#                         "text" : "4 mins",
#                         "value" : 229
#                      },
#                      "end_location" : {
#                         "lat" : 52.35433039999999,
#                         "lng" : 4.958298099999999
#                      },
#                      "html_instructions" : "Bus towards Amstelstation",
#                      "polyline" : {
#                         "points" : "wiq~Hs~c]@GD?D?JCDAJ?\\Kz@SH?H?PCAQ?w@@Q?G?G@I@]NsBPgCVcDHaA?A@O?SBgA?G@i@@g@?U@U?]@K@M@E@OBKBI?AFSBE@GFKFOFMBEBGZm@P_@Xg@dDmGbAiBJMrC_FHQ`@}@n@iAd@}@LSVc@xBiEn@qALS\\q@b@}@Vi@Zq@Ra@NYPYHYMUGMCEGECEEGEGCEGKUg@OY]q@IOc@{@GKCIEKGKEKGSUm@AEAAAAGGSi@Ma@CGEMEIAEISc@gAYo@]w@O]DI"
#                      },
#                      "start_location" : {
#                         "lat" : 52.358838,
#                         "lng" : 4.940735999999999
#                      },
#                      "transit_details" : {
#                         "arrival_stop" : {
#                            "location" : {
#                               "lat" : 52.35433039999999,
#                               "lng" : 4.958298099999999
#                            },
# ...
#                         "lat" : 52.37786639999999,
#                         "lng" : 4.9010015
#                      },
#                      "steps" : [
#                         {
#                            "distance" : {
#                               "text" : "85 m",
#                               "value" : 85
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 61
#                            },
#                            "end_location" : {
#                               "lat" : 52.3781275,
#                               "lng" : 4.899858
#                            },
#                            "html_instructions" : "Head \u003cb\u003ewest\u003c/b\u003e on \u003cb\u003eStationsplein\u003c/b\u003e",
#                            "polyline" : {
#                               "points" : "u`u~Hgf|\\ARAT@R?JQr@Op@I\\CHAH?@"
#                            },
#                            "start_location" : {
#                               "lat" : 52.37786639999999,
#                               "lng" : 4.9010015
#                            },
#                            "travel_mode" : "WALKING"
#                         }
#                      ],
#                      "travel_mode" : "WALKING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "5.2 km",
#                         "value" : 5185
#                      },
#                      "duration" : {
#                         "text" : "8 mins",
#                         "value" : 480
#                      },
#                      "end_location" : {
#                         "lat" : 52.3528141,
#                         "lng" : 4.948419
#                      },
#                      "html_instructions" : "Train towards Amersfoort Vathorst",
#                      "polyline" : {
#                         "points" : "eju~Hc~{\\BB\\mALe@T}@Rq@hAiEPq@b@_BTm@\\eANc@L]J]FWHWJa@Ni@No@Lc@Pm@BQ@EDUV_BXmBL_AFe@Fe@Fk@Da@Ba@Do@Fq@Ba@Di@Bw@@u@?g@?k@Au@Cs@Cq@Aa@Ca@EyAEuA?AGmAGmA?OCmA?cB?A@cBJsBT_CTsCx@eJXaDHw@b@cFPsBFw@ZkDDm@Do@PqBBWBa@Dc@LiAH{@@IPkAPeATkAVgAXuA\\uAP}@\\uATgAVkATeAXsAP_APiALy@XeBJm@Ji@Le@Nk@Lc@Xu@Zw@f@aA^q@`@i@b@g@h@i@TQTQZUXORIXM@AXKn@OXGZG\\Gt@KNC\\ED?b@Ab@?@?`@@RBh@FH@ZHD@^Jt@Xt@\\^RZNfAZRJRHt@`@`@TJFJFZNDB`@R`@RXNRLTJbAd@d@P^LB@@?NDNBb@H`@F@?fADB@^AnCIN?PAx@EfAERAjAOj@GJCb@IPCPG`@MVMXKrAu@BARQzAoA@A\\a@^a@Xc@Ze@^m@R]@AVk@Xo@z@_CNa@Na@h@aBb@iBPm@H[FWT{@~@{Cb@qAfAkDFSpAaEV{@pDcLnDgLnD_LpAcE`BiFFD"
#                      },
#                      "start_location" : {
#                         "lat" : 52.3793863,
#                         "lng" : 4.8997003
#                      },
#                      "transit_details" : {
#                         "arrival_stop" : {
#                            "location" : {
#                               "lat" : 52.3528141,
#                               "lng" : 4.948419
#                            },
#                            "name" : "Amsterdam Science Park"
#                         },
#                         "arrival_time" : {
#                            "text" : "11:49am",
#                            "time_zone" : "Europe/Amsterdam",
#                            "value" : 1647946140
#                         },
#                         "departure_stop" : {
#                            "location" : {
#                               "lat" : 52.3793863,
#                               "lng" : 4.8997003
#                            },
#                            "name" : "Amsterdam Centraal"
#                         },
#                         "departure_time" : {
#                            "text" : "11:41am",
#                            "time_zone" : "Europe/Amsterdam",
#                            "value" : 1647945660
#                         },
#                         "headsign" : "Amersfoort Vathorst",
#                         "line" : {
#                            "agencies" : [
#                               {
#                                  "name" : "NS",
#                                  "phone" : "011 31 30 751 5155",
#                                  "url" : "http://www.ns.nl/"
#                               }
#                            ],
#                            "name" : "Amsterdam Centraal \u003c-\u003e Amersfoort Vathorst SPR15800",
#                            "short_name" : "Sprinter",
#                            "vehicle" : {
#                               "icon" : "//maps.gstatic.com/mapfiles/transit/iw2/6/rail2.png",
#                               "name" : "Train",
#                               "type" : "HEAVY_RAIL"
#                            }
#                         },
#                         "num_stops" : 2,
#                         "trip_short_name" : "15839"
#                      },
#                      "travel_mode" : "TRANSIT"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "0.7 km",
#                         "value" : 743
#                      },
#                      "duration" : {
#                         "text" : "9 mins",
#                         "value" : 565
#                      },
#                      "end_location" : {
#                         "lat" : 52.3535392,
#                         "lng" : 4.956428300000001
#                      },
#                      "html_instructions" : "Walk to Science Park 904, 1098 XH Amsterdam, Netherlands",
#                      "polyline" : {
#                         "points" : "ycp~H{ne]?@A@A`@?B?@@@@?BABABALKEMCE_@u@ISACi@cAkAqBCECKQe@EIEKCGSa@IMEKS_@MUIOW_@SOKWGALa@@A@MCWGKNYOUCEAI?I?Q?[@{@?IBMb@iBAm@?KA}@?a@?{Bl@i@DEFGFIBK`@sANi@Le@Je@@GHWBIK[KY?A"
#                      },
#                      "start_location" : {
#                         "lat" : 52.35276959999999,
#                         "lng" : 4.948464899999999
#                      },
#                      "steps" : [
#                         {
#                            "distance" : {
#                               "text" : "39 m",
#                               "value" : 39
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 35
#                            },
#                            "end_location" : {
#                               "lat" : 52.3526707,
#                               "lng" : 4.948389199999999
#                            },
#                            "html_instructions" : "Head \u003cb\u003ewest\u003c/b\u003e toward \u003cb\u003eKruislaan\u003c/b\u003e\u003cdiv style=\"font-size:0.9em\"\u003eTake the stairs\u003c/div\u003e",
#                            "polyline" : {
#                               "points" : "ycp~H{ne]?@A@A`@?B?@@@@?BABABALKEM"
#                            },
#                            "start_location" : {
#                               "lat" : 52.35276959999999,
#                               "lng" : 4.948464899999999
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "0.3 km",
#                               "value" : 278
#                            },
#                            "duration" : {
#                               "text" : "4 mins",
#                               "value" : 211
#                            },
#                            "end_location" : {
#                               "lat" : 52.354361,
#                               "lng" : 4.9513361
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003eKruislaan\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "ecp~Hmne]CE_@u@ISACi@cAkAqBCECKQe@EIEKCGSa@IMEKS_@MUIOW_@SOKWGALa@"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3526707,
#                               "lng" : 4.948389199999999
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "9 m",
#                               "value" : 9
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 18
#                            },
#                            "end_location" : {
#                               "lat" : 52.3543394,
#                               "lng" : 4.951424400000001
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e onto \u003cb\u003eCarolina MacGillavrylaan\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "wmp~H{`f]@A@M"
#                            },
#                            "start_location" : {
#                               "lat" : 52.354361,
#                               "lng" : 4.9513361
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "21 m",
#                               "value" : 21
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 16
#                            },
#                            "end_location" : {
#                               "lat" : 52.3544038,
#                               "lng" : 4.9516034
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "smp~Hkaf]CWGK"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3543394,
#                               "lng" : 4.951424400000001
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "19 m",
#                               "value" : 19
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 14
#                            },
#                            "end_location" : {
#                               "lat" : 52.3543195,
#                               "lng" : 4.9517307
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e toward \u003cb\u003eScience Park\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "_np~Hobf]NY"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3544038,
#                               "lng" : 4.9516034
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "0.2 km",
#                               "value" : 202
#                            },
#                            "duration" : {
#                               "text" : "2 mins",
#                               "value" : 146
#                            },
#                            "end_location" : {
#                               "lat" : 52.3542413,
#                               "lng" : 4.9545398
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e onto \u003cb\u003eScience Park\u003c/b\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "omp~Hicf]OUCEAI?I?Q?[@{@?IBMb@iBAm@?KA}@?a@?{B"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3543195,
#                               "lng" : 4.9517307
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "0.2 km",
#                               "value" : 152
#                            },
#                            "duration" : {
#                               "text" : "2 mins",
#                               "value" : 109
#                            },
#                            "end_location" : {
#                               "lat" : 52.3534209,
#                               "lng" : 4.9561459
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eright\u003c/b\u003e",
#                            "maneuver" : "turn-right",
#                            "polyline" : {
#                               "points" : "_mp~H{tf]l@i@DEFGFIBK`@sANi@Le@Je@@GHWBI"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3542413,
#                               "lng" : 4.9545398
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "23 m",
#                               "value" : 23
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 16
#                            },
#                            "end_location" : {
#                               "lat" : 52.3535392,
#                               "lng" : 4.956428300000001
#                            },
#                            "html_instructions" : "Turn \u003cb\u003eleft\u003c/b\u003e\u003cdiv style=\"font-size:0.9em\"\u003eDestination will be on the right\u003c/div\u003e",
#                            "maneuver" : "turn-left",
#                            "polyline" : {
#                               "points" : "{gp~H}~f]K[KY?A"
#                            },
#                            "start_location" : {
#                               "lat" : 52.3534209,
#                               "lng" : 4.9561459
#                            },
#                            "travel_mode" : "WALKING"
#                         }
#                      ],
#                      "travel_mode" : "WALKING"
#                   }
#                ],
#                "traffic_speed_entry" : [],
#                "via_waypoint" : []
#             }
#          ],
#          "overview_polyline" : {
#             "points" : "sys~H}gj]c@ME@]z@fC~DJNw@hBGPBD`@j@vBjDtEfHVZJPl@oAPXoKpVUz@_@`Bg@jDId@KpAIf@e@|BmBlMmAnIm@lFUlDIhAIvC?tDBvBDvBZ~GvBl]fA`Qx@fRErEClBq@jJc@dD_@|B]rAgAbEmCnKeA~Cu@pBq@~Bc@lBo@dEu@|HiCf[eBtU}AhVk@tJYdHSzGWrEwB`[?b@F^PZzBzBHRDb@?`@Ef@g@pBOt@EvAEjAF@]FAR?h@?JQr@YnAER{F`@BB\\mAb@cB|A{Ft@qCr@sBp@wBt@sCd@iBdAcH\\yCTeDHaB@}AAaBGeBQsFOmDCqD@eBJsBT_CnAyNxAqPn@aI^oEj@{Ef@qCp@}CbBqHxAeHdAwGXoA\\oAt@mBfAsBdAqA~@{@p@g@l@YZOhA[hCc@l@Ih@Ad@?t@DtATtAd@tAp@ZNfAZf@TnBfAlFjCjA`@dBZhADb@?jFQzAGvBWrAYx@[lBaAtBeB|@cAt@iAr@kAXm@tBsFh@aBb@iBZiA\\sAbBmFxD}LbRol@`BiFFDFG?@Ch@B@JELKEMc@{@KWuBuD_@aAyAuCk@o@KWGANc@@MCWGKNYS[AS?m@@eAf@wBCwB?}Cr@o@NQd@_Bj@}BLa@Wu@?A"
#          },
#          "summary" : "",
#          "warnings" : [
#             "Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths."
#          ],
#          "waypoint_order" : []
#       }
#    ],
#    "status" : "OK"
# }

# %%
json_resp = json.loads(response.text)

    
for item in json_resp['routes']:
    print(item)
    print('\n')
# Out:
# {'bounds': {'northeast': {'lat': 52.37229689999999, 'lng': 4.973016100000001}, 'southwest': {'lat': 52.3522513, 'lng': 4.9389157}}, 'copyrights': 'Map data ©2022', 'legs': [{'arrival_time': {'text': '11:48am', 'time_zone': 'Europe/Amsterdam', 'value': 1647946116}, 'departure_time': {'text': '11:17am', 'time_zone': 'Europe/Amsterdam', 'value': 1647944258}, 'distance': {'text': '5.6 km', 'value': 5618}, 'duration': {'text': '31 mins', 'value': 1858}, 'end_address': 'Science Park 904, 1098 XH Amsterdam, Netherlands', 'end_location': {'lat': 52.3535392, 'lng': 4.956428300000001}, 'start_address': 'Marie Baronlaan 19, 1095 KG Amsterdam, Netherlands', 'start_location': {'lat': 52.3716209, 'lng': 4.972947}, 'steps': [{'distance': {'text': '1.1 km', 'value': 1135}, 'duration': {'text': '14 mins', 'value': 862}, 'end_location': {'lat': 52.3712922, 'lng': 4.9621277}, 'html_instructions': 'Walk to Amsterdam, Zuiderzeeweg', 'polyline': {'points': 'sys~H}gj]QEGCEACAA??@A?A??@INIVIPDFpArBb@p@JPu@hBMZCFHNDDJNRZp@fAdAbBJN~BrD~@tAYp@y@jB[t@OZqBvEe@fAc@dAO^Qd@Wr@YbAUz@CLADMn@Ox@CHG^OfAGh@EVP@@?F?R?P@T?`@?CXACAVANCVETbBC'}, 'start_location': {'lat': 52.3716209, 'lng': 4.972947}, 'steps': [{'distance': {'text': '47 m', 'value': 47}, 'duration': {'text': '1 min', 'value': 34}, 'end_location': {'lat': 52.3719775, 'lng': 4.9727105}, 'html_instructions': 'Head <b>north</b> on <b>Marie Baronlaan</b>', 'polyline': {'points': 'sys~H}gj]QEGCEACAA??@A?A??@INIVIP'}, 'start_location': {'lat': 52.3716209, 'lng': 4.972947}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.1 km', 'value': 108}, 'duration': {'text': '1 min', 'value': 81}, 'end_location': {'lat': 52.3712988, 'lng': 4.971747}, 'html_instructions': 'Turn <b>left</b> to stay on <b>Marie Baronlaan</b>', 'maneuver': 'turn-left', 'polyline': {'points': '{{s~Hmfj]DFpArBb@p@JP'}, 'start_location': {'lat': 52.3719775, 'lng': 4.9727105}, 'travel_mode': 'WALKING'}, {'distance': {'text': '63 m', 'value': 63}, 'duration': {'text': '1 min', 'value': 45}, 'end_location': {'lat': 52.3716054, 'lng': 4.970960499999999}, 'html_instructions': 'Turn <b>right</b> onto <b>Faas Wilkesstraat</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'sws~Hm`j]u@hBMZCFHN'}, 'start_location': {'lat': 52.3712988, 'lng': 4.971747}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.3 km', 'value': 268}, 'duration': {'text': '3 mins', 'value': 194}, 'end_location': {'lat': 52.3698045, 'lng': 4.9684354}, 'html_instructions': 'Turn <b>left</b> onto <b>Bob Haarmslaan</b>', 'maneuver': 'turn-left', 'polyline': {'points': 'qys~Ho{i]DDJNRZp@fAdAbBJN~BrD~@tA'}, 'start_location': {'lat': 52.3716054, 'lng': 4.970960499999999}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.5 km', 'value': 488}, 'duration': {'text': '6 mins', 'value': 352}, 'end_location': {'lat': 52.37229689999999, 'lng': 4.9626652}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'gns~Hwki]Yp@y@jB[t@OZqBvEe@fAc@dAO^Qd@Wr@YbAUz@CLADMn@Ox@CHG^OfAGh@EV'}, 'start_location': {'lat': 52.3698045, 'lng': 4.9684354}, 'travel_mode': 'WALKING'}, {'distance': {'text': '68 m', 'value': 68}, 'duration': {'text': '1 min', 'value': 69}, 'end_location': {'lat': 52.3716872, 'lng': 4.9626458}, 'html_instructions': 'Turn <b>left</b>', 'maneuver': 'turn-left', 'polyline': {'points': '{}s~Hugh]P@@?F?R?P@T?`@?'}, 'start_location': {'lat': 52.37229689999999, 'lng': 4.9626652}, 'travel_mode': 'WALKING'}, {'distance': {'text': '38 m', 'value': 38}, 'duration': {'text': '1 min', 'value': 47}, 'end_location': {'lat': 52.3717885, 'lng': 4.962108499999999}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'azs~Hqgh]CXACAVANCVET'}, 'start_location': {'lat': 52.3716872, 'lng': 4.9626458}, 'travel_mode': 'WALKING'}, {'distance': {'text': '55 m', 'value': 55}, 'duration': {'text': '1 min', 'value': 40}, 'end_location': {'lat': 52.3712922, 'lng': 4.9621277}, 'html_instructions': 'Turn <b>left</b><div style="font ...
#
#
# {'bounds': {'northeast': {'lat': 52.3736439, 'lng': 4.973016100000001}, 'southwest': {'lat': 52.3522513, 'lng': 4.9340088}}, 'copyrights': 'Map data ©2022', 'legs': [{'arrival_time': {'text': '11:48am', 'time_zone': 'Europe/Amsterdam', 'value': 1647946116}, 'departure_time': {'text': '11:09am', 'time_zone': 'Europe/Amsterdam', 'value': 1647943740}, 'distance': {'text': '7.0 km', 'value': 6972}, 'duration': {'text': '40 mins', 'value': 2376}, 'end_address': 'Science Park 904, 1098 XH Amsterdam, Netherlands', 'end_location': {'lat': 52.3535392, 'lng': 4.956428300000001}, 'start_address': 'Marie Baronlaan 19, 1095 KG Amsterdam, Netherlands', 'start_location': {'lat': 52.3716209, 'lng': 4.972947}, 'steps': [{'distance': {'text': '0.6 km', 'value': 554}, 'duration': {'text': '7 mins', 'value': 423}, 'end_location': {'lat': 52.3692943, 'lng': 4.968629}, 'html_instructions': 'Walk to Amsterdam, Bob Haarmslaan', 'polyline': {'points': 'sys~H}gj]QEGCEACAA??@A?A??@INIVIPDFpArBb@p@JPJNw@hBGPBDLNRZp@fAdAbBJN|BrD~@tAJLLPHHJPl@oA'}, 'start_location': {'lat': 52.3716209, 'lng': 4.972947}, 'steps': [{'distance': {'text': '47 m', 'value': 47}, 'duration': {'text': '1 min', 'value': 34}, 'end_location': {'lat': 52.3719775, 'lng': 4.9727105}, 'html_instructions': 'Head <b>north</b> on <b>Marie Baronlaan</b>', 'polyline': {'points': 'sys~H}gj]QEGCEACAA??@A?A??@INIVIP'}, 'start_location': {'lat': 52.3716209, 'lng': 4.972947}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.1 km', 'value': 108}, 'duration': {'text': '1 min', 'value': 81}, 'end_location': {'lat': 52.3712439, 'lng': 4.9716708}, 'html_instructions': 'Turn <b>left</b> to stay on <b>Marie Baronlaan</b>', 'maneuver': 'turn-left', 'polyline': {'points': '{{s~Hmfj]DFpArBb@p@JPJN'}, 'start_location': {'lat': 52.3719775, 'lng': 4.9727105}, 'travel_mode': 'WALKING'}, {'distance': {'text': '63 m', 'value': 63}, 'duration': {'text': '1 min', 'value': 47}, 'end_location': {'lat': 52.3715598, 'lng': 4.9710516}, 'html_instructions': 'Turn <b>right</b> onto <b>Faas Wilkesstraat</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'gws~H}_j]w@hBGP'}, 'start_location': {'lat': 52.3712439, 'lng': 4.9716708}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.3 km', 'value': 296}, 'duration': {'text': '4 mins', 'value': 223}, 'end_location': {'lat': 52.369515, 'lng': 4.9682263}, 'html_instructions': 'Turn <b>left</b> onto <b>Bob Haarmslaan</b>', 'maneuver': 'turn-left', 'polyline': {'points': 'gys~Ha|i]BDLNRZp@fAdAbBJN|BrD~@tAJLLPHHJP'}, 'start_location': {'lat': 52.3715598, 'lng': 4.9710516}, 'travel_mode': 'WALKING'}, {'distance': {'text': '40 m', 'value': 40}, 'duration': {'text': '1 min', 'value': 38}, 'end_location': {'lat': 52.3692943, 'lng': 4.968629}, 'html_instructions': 'Turn <b>left</b> onto <b>IJburglaan</b>/<wbr/><b>s114</b><div style="font-size:0.9em">Destination will be on the right</div>', 'maneuver': 'turn-left', 'polyline': {'points': 'ols~Hmji]l@oA'}, 'start_location': {'lat': 52.369515, 'lng': 4.9682263}, 'travel_mode': 'WALKING'}], 'travel_mode': 'WALKING'}, {'distance': {'text': '2.5 km', 'value': 2521}, 'duration': {'text': '3 mins', 'value': 197}, 'end_location': {'lat': 52.3730951, 'lng': 4.9340664}, 'html_instructions': 'Tram towards Centraal Station', 'polyline': {'points': 'ujs~Hmli]DHoKpVUz@Qt@Mj@Kn@[zBE\\CFEv@EXAHG\\Gf@]tA?@Ip@CH_BnKUhBc@vCIf@Id@Gl@e@~DOzBEp@Gx@ANIvC?tD@|@@x@Bz@@z@PvDFtA@F?Hn@tKfAvP?BfA|Pf@`LPdEAxBCxAAv@At@YlEW|COjAAJKt@EVSrAKh@Mj@Of@Sv@]hAETMK'}, 'start_location': {'lat': 52.3692335, 'lng': 4.9685451}, 'transit_details': {'arrival_stop': {'location': {'lat': 52.3730951, 'lng': 4.9340664}, 'name': 'Amsterdam, Rietlandpark'}, 'arrival_time': {'text': '11:20am', 'time_zone': 'Europe/Amsterdam', 'value': 1647944417}, 'departure_stop': {'location': {'lat': 52.3692335, 'lng': 4.9685451}, 'name': 'Amsterdam, Bob Haarmslaan'}, 'departure_time': {'text': '11:17am', 'time_zone': 'Europe/Amsterdam', 'value': 1647944220}, 'headsign': 'Centraal Station', 'line' ...
#
#
# {'bounds': {'northeast': {'lat': 52.37229689999999, 'lng': 4.973016100000001}, 'southwest': {'lat': 52.3534209, 'lng': 4.9438328}}, 'copyrights': 'Map data ©2022', 'legs': [{'arrival_time': {'text': '11:45am', 'time_zone': 'Europe/Amsterdam', 'value': 1647945958}, 'departure_time': {'text': '11:07am', 'time_zone': 'Europe/Amsterdam', 'value': 1647943658}, 'distance': {'text': '4.7 km', 'value': 4652}, 'duration': {'text': '38 mins', 'value': 2300}, 'end_address': 'Science Park 904, 1098 XH Amsterdam, Netherlands', 'end_location': {'lat': 52.3535392, 'lng': 4.956428300000001}, 'start_address': 'Marie Baronlaan 19, 1095 KG Amsterdam, Netherlands', 'start_location': {'lat': 52.3716209, 'lng': 4.972947}, 'steps': [{'distance': {'text': '1.1 km', 'value': 1135}, 'duration': {'text': '14 mins', 'value': 862}, 'end_location': {'lat': 52.3712922, 'lng': 4.9621277}, 'html_instructions': 'Walk to Amsterdam, Zuiderzeeweg', 'polyline': {'points': 'sys~H}gj]QEGCEACAA??@A?A??@INIVIPDFpArBb@p@JPu@hBMZCFHNDDJNRZp@fAdAbBJN~BrD~@tAYp@y@jB[t@OZqBvEe@fAc@dAO^Qd@Wr@YbAUz@CLADMn@Ox@CHG^OfAGh@EVP@@?F?R?P@T?`@?CXACAVANCVETbBC'}, 'start_location': {'lat': 52.3716209, 'lng': 4.972947}, 'steps': [{'distance': {'text': '47 m', 'value': 47}, 'duration': {'text': '1 min', 'value': 34}, 'end_location': {'lat': 52.3719775, 'lng': 4.9727105}, 'html_instructions': 'Head <b>north</b> on <b>Marie Baronlaan</b>', 'polyline': {'points': 'sys~H}gj]QEGCEACAA??@A?A??@INIVIP'}, 'start_location': {'lat': 52.3716209, 'lng': 4.972947}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.1 km', 'value': 108}, 'duration': {'text': '1 min', 'value': 81}, 'end_location': {'lat': 52.3712988, 'lng': 4.971747}, 'html_instructions': 'Turn <b>left</b> to stay on <b>Marie Baronlaan</b>', 'maneuver': 'turn-left', 'polyline': {'points': '{{s~Hmfj]DFpArBb@p@JP'}, 'start_location': {'lat': 52.3719775, 'lng': 4.9727105}, 'travel_mode': 'WALKING'}, {'distance': {'text': '63 m', 'value': 63}, 'duration': {'text': '1 min', 'value': 45}, 'end_location': {'lat': 52.3716054, 'lng': 4.970960499999999}, 'html_instructions': 'Turn <b>right</b> onto <b>Faas Wilkesstraat</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'sws~Hm`j]u@hBMZCFHN'}, 'start_location': {'lat': 52.3712988, 'lng': 4.971747}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.3 km', 'value': 268}, 'duration': {'text': '3 mins', 'value': 194}, 'end_location': {'lat': 52.3698045, 'lng': 4.9684354}, 'html_instructions': 'Turn <b>left</b> onto <b>Bob Haarmslaan</b>', 'maneuver': 'turn-left', 'polyline': {'points': 'qys~Ho{i]DDJNRZp@fAdAbBJN~BrD~@tA'}, 'start_location': {'lat': 52.3716054, 'lng': 4.970960499999999}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.5 km', 'value': 488}, 'duration': {'text': '6 mins', 'value': 352}, 'end_location': {'lat': 52.37229689999999, 'lng': 4.9626652}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'gns~Hwki]Yp@y@jB[t@OZqBvEe@fAc@dAO^Qd@Wr@YbAUz@CLADMn@Ox@CHG^OfAGh@EV'}, 'start_location': {'lat': 52.3698045, 'lng': 4.9684354}, 'travel_mode': 'WALKING'}, {'distance': {'text': '68 m', 'value': 68}, 'duration': {'text': '1 min', 'value': 69}, 'end_location': {'lat': 52.3716872, 'lng': 4.9626458}, 'html_instructions': 'Turn <b>left</b>', 'maneuver': 'turn-left', 'polyline': {'points': '{}s~Hugh]P@@?F?R?P@T?`@?'}, 'start_location': {'lat': 52.37229689999999, 'lng': 4.9626652}, 'travel_mode': 'WALKING'}, {'distance': {'text': '38 m', 'value': 38}, 'duration': {'text': '1 min', 'value': 47}, 'end_location': {'lat': 52.3717885, 'lng': 4.962108499999999}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'azs~Hqgh]CXACAVANCVET'}, 'start_location': {'lat': 52.3716872, 'lng': 4.9626458}, 'travel_mode': 'WALKING'}, {'distance': {'text': '55 m', 'value': 55}, 'duration': {'text': '1 min', 'value': 40}, 'end_location': {'lat': 52.3712922, 'lng': 4.9621277}, 'html_instructions': 'Turn <b>left</b><div style="font ...
#
#
# {'bounds': {'northeast': {'lat': 52.3793863, 'lng': 4.973016100000001}, 'southwest': {'lat': 52.3526442, 'lng': 4.8996806}}, 'copyrights': 'Map data ©2022', 'legs': [{'arrival_time': {'text': '11:58am', 'time_zone': 'Europe/Amsterdam', 'value': 1647946706}, 'departure_time': {'text': '11:16am', 'time_zone': 'Europe/Amsterdam', 'value': 1647944160}, 'distance': {'text': '11.5 km', 'value': 11481}, 'duration': {'text': '42 mins', 'value': 2546}, 'end_address': 'Science Park 904, 1098 XH Amsterdam, Netherlands', 'end_location': {'lat': 52.3535392, 'lng': 4.956428300000001}, 'start_address': 'Marie Baronlaan 19, 1095 KG Amsterdam, Netherlands', 'start_location': {'lat': 52.3716209, 'lng': 4.972947}, 'steps': [{'distance': {'text': '0.6 km', 'value': 554}, 'duration': {'text': '7 mins', 'value': 423}, 'end_location': {'lat': 52.3692943, 'lng': 4.968629}, 'html_instructions': 'Walk to Amsterdam, Bob Haarmslaan', 'polyline': {'points': 'sys~H}gj]QEGCEACAA??@A?A??@INIVIPDFpArBb@p@JPJNw@hBGPBDLNRZp@fAdAbBJN|BrD~@tAJLLPHHJPl@oA'}, 'start_location': {'lat': 52.3716209, 'lng': 4.972947}, 'steps': [{'distance': {'text': '47 m', 'value': 47}, 'duration': {'text': '1 min', 'value': 34}, 'end_location': {'lat': 52.3719775, 'lng': 4.9727105}, 'html_instructions': 'Head <b>north</b> on <b>Marie Baronlaan</b>', 'polyline': {'points': 'sys~H}gj]QEGCEACAA??@A?A??@INIVIP'}, 'start_location': {'lat': 52.3716209, 'lng': 4.972947}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.1 km', 'value': 108}, 'duration': {'text': '1 min', 'value': 81}, 'end_location': {'lat': 52.3712439, 'lng': 4.9716708}, 'html_instructions': 'Turn <b>left</b> to stay on <b>Marie Baronlaan</b>', 'maneuver': 'turn-left', 'polyline': {'points': '{{s~Hmfj]DFpArBb@p@JPJN'}, 'start_location': {'lat': 52.3719775, 'lng': 4.9727105}, 'travel_mode': 'WALKING'}, {'distance': {'text': '63 m', 'value': 63}, 'duration': {'text': '1 min', 'value': 47}, 'end_location': {'lat': 52.3715598, 'lng': 4.9710516}, 'html_instructions': 'Turn <b>right</b> onto <b>Faas Wilkesstraat</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'gws~H}_j]w@hBGP'}, 'start_location': {'lat': 52.3712439, 'lng': 4.9716708}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.3 km', 'value': 296}, 'duration': {'text': '4 mins', 'value': 223}, 'end_location': {'lat': 52.369515, 'lng': 4.9682263}, 'html_instructions': 'Turn <b>left</b> onto <b>Bob Haarmslaan</b>', 'maneuver': 'turn-left', 'polyline': {'points': 'gys~Ha|i]BDLNRZp@fAdAbBJN|BrD~@tAJLLPHHJP'}, 'start_location': {'lat': 52.3715598, 'lng': 4.9710516}, 'travel_mode': 'WALKING'}, {'distance': {'text': '40 m', 'value': 40}, 'duration': {'text': '1 min', 'value': 38}, 'end_location': {'lat': 52.3692943, 'lng': 4.968629}, 'html_instructions': 'Turn <b>left</b> onto <b>IJburglaan</b>/<wbr/><b>s114</b><div style="font-size:0.9em">Destination will be on the right</div>', 'maneuver': 'turn-left', 'polyline': {'points': 'ols~Hmji]l@oA'}, 'start_location': {'lat': 52.369515, 'lng': 4.9682263}, 'travel_mode': 'WALKING'}], 'travel_mode': 'WALKING'}, {'distance': {'text': '4.9 km', 'value': 4914}, 'duration': {'text': '10 mins', 'value': 600}, 'end_location': {'lat': 52.37771799999999, 'lng': 4.901041}, 'html_instructions': 'Tram towards Centraal Station', 'polyline': {'points': 'ujs~Hmli]DHoKpVUz@Qt@Mj@Kn@[zBE\\CFEv@EXAHG\\Gf@]tA?@Ip@CH_BnKUhBc@vCIf@Id@Gl@e@~DOzBEp@Gx@ANIvC?tD@|@@x@Bz@@z@PvDFtA@F?Hn@tKfAvP?BfA|Pf@`LPdEAxBCxAAv@At@YlEW|COjAAJKt@EVSrAKh@Mj@Of@Sv@]hAETOj@c@dBs@tCi@rBK^Od@Od@Un@Ob@Yr@[|@c@vAMf@K`@CHI\\Ib@I`@Ox@Kx@In@In@KfAAT]nD[nDCXWbDWzCSbCQvBS~B?@KvACXGt@MbBSrCAJSrCUtCQtCEh@IjA[nEEt@S|CAPCf@G|@KfBGr@?LEd@A^Et@APC^?@E~@Cf@Cb@A^AZCz@A\\C`@Aj@Cx@Ab@Cf@Ab@?DAZAXCXAZC\\AJEx@ABShD_@bFOvBOjBUbDAJATIhAAJ?F?F@F?H@F@FBDBHBDBFDBFF`@b@|@z@RR@B@B@BBF@J@D@F?H@H?FAF?FAHALANAHCFAH_@tAMh@AJ?LEhAEjAF@'}, 'start_location': {'lat': 52.3692335, 'lng': 4.9685451}, 'transit_details': {'arrival_stop': {'location': {'lat': 52.37771799999999, 'lng': 4.901041}, 'name': 'Amste ...

# %%
route = json_resp['routes'][1]['legs'][0]
print(route['arrival_time'])
print(route['departure_time'])
print(route['distance']['text'])
print(route['duration']['text'])
print(route['start_address'].split(',')[0])
print(route['end_address'].split(',')[0])
print(route['end_location'])
for item in route:
    print(item)
# Out:
# {'text': '11:48am', 'time_zone': 'Europe/Amsterdam', 'value': 1647946116}
# {'text': '11:09am', 'time_zone': 'Europe/Amsterdam', 'value': 1647943740}
# 7.0 km
# 40 mins
# Marie Baronlaan 19
# Science Park 904
# {'lat': 52.3535392, 'lng': 4.956428300000001}
# arrival_time
# departure_time
# distance
# duration
# end_address
# end_location
# start_address
# start_location
# steps
# traffic_speed_entry
# via_waypoint

# %%
ts = int(route['arrival_time']['value'])
print(datetime.datetime.utcfromtimestamp(ts).strftime('%H:%M'))

ts = int(route['departure_time']['value'])
print(datetime.datetime.utcfromtimestamp(ts).strftime('%H:%M'))
# Out:
# 10:48
# 10:09

# %%
transit_modes = []

for step in json_resp['routes'][1]['legs'][0]['steps']:
    print(step['duration']['text'])
    print(step['distance']['text'])
    print(step['start_location'])
    print(step['end_location'])
    print(step['travel_mode'])

    if step['travel_mode'] == 'TRANSIT':
        print(step['transit_details']['departure_stop']['name'])
        print(step['transit_details']['departure_time']['text'])
        print(step['transit_details']['arrival_stop']['name'])
        print(step['transit_details']['arrival_time']['text'])
        print(step['transit_details']['line']['vehicle']['name'])
        transit_modes.append(step['transit_details']['line']['vehicle']['name'])
    else:
        print(step['duration']['value'])
        if step['duration']['value'] > 60:
            transit_modes.append(step['travel_mode'])
            
    print('\n')
#     print(step)
    print('\n')
# Out:
# 7 mins
# 0.6 km
# {'lat': 52.3716209, 'lng': 4.972947}
# {'lat': 52.3692943, 'lng': 4.968629}
# WALKING
# 423
#
#
#
#
# 3 mins
# 2.5 km
# {'lat': 52.3692335, 'lng': 4.9685451}
# {'lat': 52.3730951, 'lng': 4.9340664}
# TRANSIT
# Amsterdam, Bob Haarmslaan
# 11:17am
# Amsterdam, Rietlandpark
# 11:20am
# Tram
#
#
#
#
# 4 mins
# 0.4 km
# {'lat': 52.3731219, 'lng': 4.9340629}
# {'lat': 52.3735681, 'lng': 4.9387367}
# WALKING
# 269
#
#
#
#
# 5 mins
# 1.8 km
# {'lat': 52.37361689999999, 'lng': 4.9390394}
# {'lat': 52.358838, 'lng': 4.940735999999999}
# TRANSIT
# Amsterdam, C. van Eesterenlaan
# 11:29am
# Amsterdam, Valentijnkade
# 11:34am
# Bus
#
#
#
#
# 4 mins
# 1.6 km
# {'lat': 52.358838, 'lng': 4.940735999999999}
# {'lat': 52.35433039999999, 'lng': 4.958298099999999}
# TRANSIT
# Amsterdam, Valentijnkade
# 11:42am
# Science Park Terra
# 11:46am
# Bus
#
#
#
#
# 2 mins
# 0.2 km
# {'lat': 52.3543424, 'lng': 4.9582806}
# {'lat': 52.3535392, 'lng': 4.956428300000001}
# WALKING
# 114

# %%
transit_modes
# Out:
# ['WALKING', 'Tram', 'WALKING', 'Bus', 'Bus', 'WALKING']

# %%
def get_transport_icons(route):
    transit_modes = []
    icons = []

    for step in route['steps']:
        if step['travel_mode'] == 'TRANSIT':
            mode = step['transit_details']['line']['vehicle']['name']
            if mode == 'Bus':
                icons.append('ph-bus')
            elif mode == 'Train':
                icons.append('ph-train-regional')
            elif mode == 'Metro':
                icons.append('ph-train-simple')
            elif mode == 'Tram':
                icons.append('ph-train')
            else:
                icons.append('ph-question')
        else:
            if step['duration']['value'] > 60:
                icons.append('ph-person-simple-walk')
                
    return icons

# %%
def get_journey_details(route):
    journey_details = []

    for i in range(len(route['steps'])):
        step = route['steps'][i]

        if step['travel_mode'] == 'WALKING':
            if step['duration']['value'] > 60:
                step_duration = step['duration']['text']
                step_distance = step['distance']['text']
                
                if i == 0:
                    step_start = route['start_address'].split(',')[0]
                    step_end = route['steps'][i+1]['transit_details']['departure_stop']['name']
                elif i == len(route['steps']) - 1:
                    step_start = route['steps'][i-1]['transit_details']['arrival_stop']['name']
                    step_end = route['end_address'].split(',')[0]
                else:
                    step_start = route['steps'][i-1]['transit_details']['arrival_stop']['name']
                    step_end = route['steps'][i+1]['transit_details']['departure_stop']['name']
                    
                step_travel_mode = step['travel_mode']

                if i == len(route['steps']) - 1:
                    ts_dep = int(route['steps'][i-1]['transit_details']['arrival_time']['value'])
                    step_dep_time = datetime.datetime.utcfromtimestamp(ts_dep).strftime('%H:%M')
                    ts_arr = int(route['steps'][i-1]['transit_details']['arrival_time']['value']) + int(step['duration']['value'])
                    step_arr_time = datetime.datetime.utcfromtimestamp(ts_arr).strftime('%H:%M')
                else:
                    ts_dep = int(route['steps'][i+1]['transit_details']['departure_time']['value']) - int(step['duration']['value'])
                    step_dep_time = datetime.datetime.utcfromtimestamp(ts_dep).strftime('%H:%M')
                    ts_arr = int(route['steps'][i+1]['transit_details']['departure_time']['value'])
                    step_arr_time = datetime.datetime.utcfromtimestamp(ts_arr).strftime('%H:%M')

                step_details = [step_duration, step_distance, step_start, step_dep_time, step_end, step_arr_time, step_travel_mode]
                journey_details.append(step_details)

        if step['travel_mode'] == 'TRANSIT':
            step_duration = step['duration']['text']
            step_distance = step['distance']['text']
            step_dep_stop = step['transit_details']['departure_stop']['name']
            ts_dep = int(step['transit_details']['departure_time']['value'])
            step_dep_time = datetime.datetime.utcfromtimestamp(ts_dep).strftime('%H:%M')
            step_arr_stop = step['transit_details']['arrival_stop']['name']
            ts_arr = int(step['transit_details']['arrival_time']['value'])
            step_arr_time = datetime.datetime.utcfromtimestamp(ts_arr).strftime('%H:%M')
            step_travel_mode = step['travel_mode']
            step_headsign = step['transit_details']['headsign']
            step_shortname = step['transit_details']['line']['short_name']
            step_num_stops = step['transit_details']['line']['num_stops']
            step_details = [step_duration, step_distance, step_dep_stop, step_dep_time, step_arr_stop, step_arr_time, step_headsign, step_shortname, step_num_stops, step_travel_mode]
            journey_details.append(step_details)

    journey_details.append(len(journey_details))
    
    return journey_details

# %%
def parse_json(json_resp):
    if json_resp['status'] == 'OK':
        all_journeys = []
        num_journeys = 0

        for i in range(len(json_resp['routes'])):
            route = json_resp['routes'][i]['legs'][0]
            if 'arrival_time' in route:
                num_journeys += 1
                walk_time = 0
                for step in route['steps']:
                    if step['travel_mode'] == 'WALKING':
                        if step['duration']['value'] > 60:
#                             print(step['duration']['value'])
                            walk_time += step['duration']['value']
#                 print(walk_time)
                walk_time = round(walk_time / 60)
#                 print(walk_time)
#                 print('\n')

                ts_arr = int(route['arrival_time']['value'])
                arrival_time = datetime.datetime.utcfromtimestamp(ts_arr).strftime('%H:%M')
                ts_dep = int(route['departure_time']['value'])
                departure_time = datetime.datetime.utcfromtimestamp(ts_dep).strftime('%H:%M')
                distance = route['distance']['text']
                duration = route['duration']['text']
                start_address = route['start_address'].split(',')[0]
                end_address = route['end_address'].split(',')[0]
                end_weather = get_darksky_features(route['end_location']['lng'], route['end_location']['lat'], datetime.datetime.today())
                print(end_weather)
#                 weather_icon = determine_weather_icon(end_weather['hourly']['icon'])
                weather_result = [end_weather['hourly']['summary'], end_weather['currently']['precipProbability'], end_weather['currently']['temperature']]
                icons = get_transport_icons(route)
                route_details = get_journey_details(route)
                results = [departure_time, arrival_time, duration, walk_time, icons, len(icons)-1, distance, start_address, end_address, weather_result, route_details]
                all_journeys.append(results)
        all_journeys.append(num_journeys)

    else:
        all_journeys = ['No routes found']

    return all_journeys

# %%
j = parse_json(json_resp)
# Out:
# {'latitude': 52.3535392, 'longitude': 4.956428300000001, 'timezone': 'Europe/Amsterdam', 'currently': {'time': 1648130068, 'summary': 'Clear', 'icon': 'clear-day', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 17.81, 'apparentTemperature': 17.81, 'dewPoint': 4.39, 'humidity': 0.41, 'pressure': 1029.5, 'windSpeed': 10.25, 'windGust': 10.25, 'windBearing': 33, 'cloudCover': 0.06, 'uvIndex': 2, 'visibility': 16.093, 'ozone': 353.6}, 'hourly': {'summary': 'Clear throughout the day.', 'icon': 'clear-day', 'data': [{'time': 1648076400, 'summary': 'Clear', 'icon': 'clear-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 8.75, 'apparentTemperature': 7.48, 'dewPoint': 4.99, 'humidity': 0.77, 'pressure': 1030.5, 'windSpeed': 8.33, 'windGust': 8.69, 'windBearing': 67, 'cloudCover': 0.01, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 346.5}, {'time': 1648080000, 'summary': 'Clear', 'icon': 'clear-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 8.19, 'apparentTemperature': 7.06, 'dewPoint': 4.34, 'humidity': 0.77, 'pressure': 1030.1, 'windSpeed': 7.31, 'windGust': 7.73, 'windBearing': 68, 'cloudCover': 0.01, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 346}, {'time': 1648083600, 'summary': 'Clear', 'icon': 'clear-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 7.7, 'apparentTemperature': 6.74, 'dewPoint': 3.8, 'humidity': 0.76, 'pressure': 1030.1, 'windSpeed': 6.35, 'windGust': 6.76, 'windBearing': 69, 'cloudCover': 0.02, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 347.2}, {'time': 1648087200, 'summary': 'Clear', 'icon': 'clear-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 6.95, 'apparentTemperature': 6.29, 'dewPoint': 4.51, 'humidity': 0.84, 'pressure': 1029.9, 'windSpeed': 5.04, 'windGust': 6.35, 'windBearing': 53, 'cloudCover': 0.02, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 347.7}, {'time': 1648090800, 'summary': 'Clear', 'icon': 'clear-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 6.36, 'apparentTemperature': 6.36, 'dewPoint': 4.08, 'humidity': 0.85, 'pressure': 1029.7, 'windSpeed': 4.35, 'windGust': 6.15, 'windBearing': 48, 'cloudCover': 0.04, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 347.9}, {'time': 1648094400, 'summary': 'Clear', 'icon': 'clear-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 5.63, 'apparentTemperature': 5.63, 'dewPoint': 3.58, 'humidity': 0.87, 'pressure': 1029.5, 'windSpeed': 3.57, 'windGust': 5.11, 'windBearing': 47, 'cloudCover': 0.07, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 347.1}, {'time': 1648098000, 'summary': 'Clear', 'icon': 'clear-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 4.92, 'apparentTemperature': 4.92, 'dewPoint': 3.28, 'humidity': 0.89, 'pressure': 1029.7, 'windSpeed': 3.78, 'windGust': 5.17, 'windBearing': 42, 'cloudCover': 0.07, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 347.1}, {'time': 1648101600, 'summary': 'Clear', 'icon': 'clear-day', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 5.37, 'apparentTemperature': 5.37, 'dewPoint': 2.93, 'humidity': 0.84, 'pressure': 1030, 'windSpeed': 3.45, 'windGust': 4.56, 'windBearing': 26, 'cloudCover': 0.12, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 345.7}, {'time': 1648105200, 'summary': 'Clear', 'icon': 'clear-day', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 6.98, 'apparentTemperature': 6.98, 'dewPoint': 3.57, 'humidity': 0.79, 'pressure': 1030.2, 'windSpeed': 3.2, 'windGust': 4.58, 'windBearing': 22, 'cloudCover': 0.17, 'uvIndex': 0, 'visibility': 16.093, 'ozone': 346.4}, {'time': 1648108800, 'summary': 'Clear', 'icon': 'clear-day', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 8.83, 'apparentTemperature': 8.83, 'dewPoint': 3.99, 'humidity': 0.72, 'pressure': 1030.3, 'windSpeed': 3.42, 'windGust': 5.84, 'windBearing': 22, 'cloudCover': 0.28, 'uvIndex': 1, 'visibility': 16.093, 'ozone': 346.9}, {'time': 1648112400, 'summary': ' ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27776/2050697733.py in <module>
# ----> 1 j = parse_json(json_resp)
#
# ~\AppData\Local\Temp/ipykernel_27776/3075361018.py in parse_json(json_resp)
#      32                 weather_result = [end_weather['hourly']['summary'], end_weather['currently']['precipProbability'], end_weather['currently']['temperature']]
#      33                 icons = get_transport_icons(route)
# ---> 34                 route_details = get_journey_details(route)
#      35                 results = [departure_time, arrival_time, duration, walk_time, icons, len(icons)-1, distance, start_address, end_address, weather_result, route_details]
#      36                 all_journeys.append(results)
#
# ~\AppData\Local\Temp/ipykernel_27776/868601788.py in get_journey_details(route)
#      48             step_headsign = step['transit_details']['headsign']
#      49             step_shortname = step['transit_details']['line']['short_name']
# ---> 50             step_num_stops = step['transit_details']['line']['num_stops']
#      51             step_details = [step_duration, step_distance, step_dep_stop, step_dep_time, step_arr_stop, step_arr_time, step_headsign, step_shortname, step_num_stops, step_travel_mode]
#      52             journey_details.append(step_details)
#
# KeyError: 'num_stops'

# %%
j
# Out:
# [['10:07',
#   '11:03',
#   '56 mins',
#   10,
#   ['ph-person-simple-walk',
#    'ph-bus',
#    'ph-bus',
#    'ph-person-simple-walk',
#    'ph-bus',
#    'ph-bus',
#    'ph-person-simple-walk'],
#   6,
#   '20.4 km',
#   'Ruth Firststraat 9',
#   'Science Park 904',
#   ['Clear throughout the day.', 0, 17.83],
#   [['4 mins',
#     '0.3 km',
#     'Ruth Firststraat 9',
#     '10:07',
#     'Purmerend, Moeder Teresastraat',
#     '10:11',
#     'WALKING'],
#    ['4 mins',
#     '3.4 km',
#     'Purmerend, Moeder Teresastraat',
#     '10:11',
#     'Ilpendam, Ilpendam',
#     '10:15',
#     'Amsterdam Noord',
#     '307',
#     'TRANSIT'],
#    ['14 mins',
#     '11.4 km',
#     'Ilpendam, Ilpendam',
#     '10:19',
#     'Amsterdam, IJtunnel',
#     '10:33',
#     'Amsterdam Centraal',
#     '306',
#     'TRANSIT'],
#    ['5 mins',
#     '0.3 km',
#     'Amsterdam, IJtunnel',
#     '10:37',
#     'Amsterdam, Kadijksplein',
#     '10:42',
#     'WALKING'],
#    ['8 mins',
#     '2.8 km',
#     'Amsterdam, Kadijksplein',
#     '10:42',
#     'Amsterdam, Molukkenstraat',
#     '10:50',
#     'Muiderpoortstation',
#     '22',
#     'TRANSIT'],
#    ['5 mins',
#     '2.0 km',
#     'Amsterdam, Molukkenstraat',
#     '10:57',
#     'Science Park Terra',
#     '11:01',
#     'Amstelstation',
#     '40',
#     'TRANSIT'],
#    ['2 mins',
#     '0.2 km',
#     'Science Park Terra',
#     '11:01',
#     'Science Park 904',
#     '11:03',
#     'WALKING'],
#    7]],
#  ['10:07',
#   '11:10',
#   '1 hour 3 mins',
#   13,
#   ['ph-person-simple-walk',
#    'ph-bus',
#    'ph-bus',
#    'ph-train-regional',
#    'ph-person-simple-walk'],
#   4,
#   '22.1 km',
#   'Ruth Firststraat 9',
#   'Science Park 904',
#   ['Clear throughout the day.', 0, 17.83],
#   [['4 mins',
#     '0.3 km',
#     'Ruth Firststraat 9',
#     '10:07',
#     'Purmerend, Moeder Teresastraat',
#     '10:11',
#     'WALKING'],
#    ['4 mins',
#     '3.4 km',
#     'Purmerend, Moeder Teresastraat',
#     '10:11',
#     'Ilpendam, Ilpendam',
#     '10:15',
#     'Amsterdam Noord',
#     '307',
#     'TRANSIT'],
#    ['17 mins',
#     '12.6 km',
#     'Ilpendam, Ilpendam',
#     '10:19',
#     'Amsterdam, Centraal Station',
#     '10:36',
#     'Amsterdam Centraal',
#     '306',
#     'TRANSIT'],
#    ['8 mins',
#     '5.0 km',
#     'Amsterdam Centraal',
#     '10:53',
#     'Amsterdam Science Park',
#     '11:01',
#     'Zwolle',
#     'Sprinter',
#     'TRANSIT'],
#    ['9 mins',
#     '0.7 km',
#     'Amsterdam Science Park',
#     '11:01',
#     'Science Park 904',
#     '11:10',
#     'WALKING'],
#    5]],
#  ['10:11',
#   '11:10',
#   '59 mins',
#   24,
#   ['ph-person-simple-walk',
#    'ph-bus',
#    'ph-train-regional',
#    'ph-person-simple-walk'],
#   3,
#   '22.5 km',
#   'Ruth Firststraat 9',
#   'Science Park 904',
#   ['Clear throughout the day.', 0, 17.83],
#   [['14 mins',
#     '1.1 km',
#     'Ruth Firststraat 9',
#     '10:11',
#     'Purmerend, Vurige Staart',
#     '10:26',
#     'WALKING'],
#    ['20 mins',
#     '15.6 km',
#     'Purmerend, Vurige Staart',
#     '10:26',
#     'Amsterdam, Centraal Station',
#     '10:46',
#     'Amsterdam Centraal',
#     '305',
#     'TRANSIT'],
#    ['8 mins',
#     '5.0 km',
#     'Amsterdam Centraal',
#     '10:53',
#     'Amsterdam Science Park',
#     '11:01',
#     'Zwolle',
#     'Sprinter',
#     'TRANSIT'],
#    ['9 mins',
#     '0.7 km',
#     'Amsterdam Science Park',
#     '11:01',
#     'Science Park 904',
#     '11:10',
#     'WALKING'],
#    4]],
#  ['10:07',
#   '11:19',
#   '1 hour 12 mins',
#   5,
#   ['ph-person-simple-walk',
#    'ph-bus',
#    'ph-bus',
#    'ph-question',
#    'ph-bus',
#    'ph-person-simple-walk'],
#   5,
#   '24.2 km',
#   'Ruth Firststraat 9',
#   'Science Park 904',
#   ['Clear throughout the day.', 0, 17.83],
#   [['4 mins',
#     '0.3 km',
#     'Ruth Firststraat 9',
#     '10:07',
#     'Purmerend, Moeder Teresastraat',
#     '10:11',
#     'WALKING'],
#    ['4 mins',
#     '3.4 km',
#     'Purmerend, Moeder Teresastraat',
#     '10:11',
#     'Ilpendam, Ilpendam',
#     '10:15',
#     'Amsterdam Noord',
#     '307',
#     'TRANSIT'],
#    ['15 mins',
#     '12.1 km',
#     'Ilpendam, Ilpendam',
#     '10:19',
#     'Amsterdam, Prins Hendrikkade',
#     '10:34',
#     'Amsterdam Centraal',
#     '306',
#     'TRANSIT'],
#    ['7 mins',
#     '4.0 km',
#     'Central Station',
#     '10:41',
#     'Amsterdam, Amstelstation',
#     '10:47',
#     'Gein',
#     '54',
#     'TRANSIT'],
#    ['11 mins',
#     '4.2 km',
#     'Amsterdam, Amstelstation',
#     '11:07',
#     'Science Park Terra',
#     '11:17',
#     'Muiderpoortstation',
#     '40',
#     'TRANSIT'],
#    ['1 min',
#     '93 m',
#     'Science Park Terra',
#     '11:17',
#     'Science Park 904',
#     '11:18',
#     'WALKING'],
#    6]],
#  4]

# %%
def go_walk(last_departure_stop, last_departure_time, last_arrival_stop, last_arrival_time, final_destination, final_arrival_time, walking_time, last_walking_time):
    
    # read to use the csv of line 40
    df = pd.read_csv('lijn40_ordered.csv')
    
    # the orderlocation of the busstop where the last leg starts
    A = df[df['haltenaam'].str.contains(last_departure_stop)].index.values[0]
    
    # the order location of the arrival stop
    B = df[df['haltenaam'].str.contains(last_arrival_stop)].index.values[0]
    
    # get all stops in between the start and arrival of the last leg and order them correctly
    if A < B:
        stoplist = df[A:B+1]['haltenaam']
    if B < A:
        stoplist = df[B:A+1]['haltenaam'][::-1]
    
    # get the walking time and distance from each stop to the final destination
    results = []
    for stop in stoplist[:-1]:
        url = "https://maps.googleapis.com/maps/api/directions/json?origin={origin}&destination={destination}&mode=walking&key=".format(origin=stop, destination=final_destination) + GOOGLE_MAPS_KEY
        payload={}
        headers = {}
        response = requests.request("GET", url, headers=headers, data=payload)
        response = json.loads(response.text)
        
        # get duration and distance
        duration = response['routes'][0]['legs'][0]['duration']['text']
        distance = response['routes'][0]['legs'][0]['distance']['text']
        
        # get start address (for control if it picked the right lcoation)
        start_address = response['routes'][0]['legs'][0]['start_address'].split(',')[0]
        
        duration_int = int(duration.split(' ')[0])
        duration = duration_int - last_walking_time
        final_walk_time = duration_int + walking_time - last_walking_time 
#         walk_without_last_leg = 
        
        # order results that are returened
        results.append([start_address, duration, distance, final_walk_time])
        
        # get lng and lat of end location for weather
        end = response['routes'][0]['legs'][0]['end_location']
    
    return results


last_departure_stop = j[0][-1][-3][2]
last_departure_time = j[0][-1][-3][3]
last_arrival_stop = j[0][-1][-3][4]
last_arrival_time = j[0][-1][-3][5]
final_destination = j[0][8]
final_arrival_time = j[0][1]
walking_time = j[0][3]
last_walking_time = int(j[0][-1][-2][0].split(' ')[0])

go_walk(last_departure_stop, last_departure_time, last_arrival_stop, last_arrival_time, final_destination, final_arrival_time, walking_time, last_walking_time)
# Out:
# [['Molukkenstraat', 19, '1.7 km', 29],
#  ['Valentijnkade', 13, '1.2 km', 23],
#  ['Carolina MacGillavrylaan', 5, '0.5 km', 15],
#  ["Science Park A'dam", 5, '0.5 km', 15]]

# %%
j[0][3]
# int(j[0][-1][-2][0].split(' ')[0])
# Out:
# 10

# %%
df = pd.read_csv('lijn40_ordered.csv')
df[df['haltenaam'].str.contains(last_arrival_stop)].index.values[0]
# Out:
# 5

# %%
route = json_resp['routes'][1]['legs'][0]
route['steps'][4]['transit_details']['headsign']
route['steps'][4]['transit_details']['num_stops']
# Out:
# 2

# %%
get_darksky_features(route['end_location']['lng'], route['end_location']['lat'], datetime.datetime.today())
# Out:
# {'latitude': 52.3535392,
#  'longitude': 4.956428300000001,
#  'timezone': 'Europe/Amsterdam',
#  'currently': {'time': 1648116064,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 13.8,
#   'apparentTemperature': 13.8,
#   'dewPoint': 4.83,
#   'humidity': 0.55,
#   'pressure': 1030.7,
#   'windSpeed': 5.51,
#   'windGust': 7.68,
#   'windBearing': 26,
#   'cloudCover': 0.43,
#   'uvIndex': 2,
#   'visibility': 16.093,
#   'ozone': 349.7},
#  'hourly': {'summary': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1648076400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 8.75,
#     'apparentTemperature': 7.48,
#     'dewPoint': 4.99,
#     'humidity': 0.77,
#     'pressure': 1030.5,
#     'windSpeed': 8.33,
#     'windGust': 8.69,
#     'windBearing': 67,
#     'cloudCover': 0.01,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 346.5},
#    {'time': 1648080000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 8.19,
#     'apparentTemperature': 7.06,
#     'dewPoint': 4.34,
#     'humidity': 0.77,
#     'pressure': 1030.1,
#     'windSpeed': 7.31,
#     'windGust': 7.73,
#     'windBearing': 68,
#     'cloudCover': 0.01,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 346},
#    {'time': 1648083600,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 7.7,
#     'apparentTemperature': 6.74,
#     'dewPoint': 3.8,
#     'humidity': 0.76,
#     'pressure': 1030.1,
#     'windSpeed': 6.35,
#     'windGust': 6.76,
#     'windBearing': 69,
#     'cloudCover': 0.02,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 347.2},
#    {'time': 1648087200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 6.95,
#     'apparentTemperature': 6.29,
#     'dewPoint': 4.51,
#     'humidity': 0.84,
#     'pressure': 1029.9,
#     'windSpeed': 5.04,
#     'windGust': 6.35,
#     'windBearing': 53,
#     'cloudCover': 0.02,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 347.7},
#    {'time': 1648090800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 6.36,
#     'apparentTemperature': 6.36,
#     'dewPoint': 4.08,
#     'humidity': 0.85,
#     'pressure': 1029.7,
#     'windSpeed': 4.35,
#     'windGust': 6.15,
#     'windBearing': 48,
#     'cloudCover': 0.04,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 347.9},
#    {'time': 1648094400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 5.63,
#     'apparentTemperature': 5.63,
#     'dewPoint': 3.58,
#     'humidity': 0.87,
#     'pressure': 1029.5,
#     'windSpeed': 3.57,
#     'windGust': 5.11,
#     'windBearing': 47,
#     'cloudCover': 0.07,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 347.1},
#    {'time': 1648098000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 4.92,
#     'apparentTemperature': 4.92,
#     'dewPoint': 3.28,
#     'humidity': 0.89,
#     'pressure': 1029.7,
#     'windSpeed': 3.78,
#     'windGust': 5.17,
#     'windBearing': 42,
#     'cloudCover': 0.07,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 347.1},
#    {'time': 1648101600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 4.7,
#     'apparentTemperature': 4.7,
#     'dewPoint': 2.93,
#     'humidity': 0.88,
#     'pressure': 1030,
#     'windSpeed': 3.45,
#     'windGust': 4.56,
#     'windBearing': 26,
#     'cloudCover': 0.12,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 345.7},
#    {'time': 1648105200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 6.37,
#     'apparentTemperature': 6.37,
#     'dewPoint': 3.54,
#     'humidity': 0.82,
#     'pressure': 1030.3,
#     'windSpeed': 3.2,
#     'windGust': 4.58,
#     'windBearing': 22,
#     'cloudCover': 0.26,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 346.4},
#    {'time': 1648108800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 8.75,
#     'apparentTemperature': 8.75,
#     'dewPoint': 3.98,
#     'humidity': 0.72,
#     'pressure': 1030.4,
#     'windSpeed': 3.42,
#     'windGust': 5.83,
#     'windBearing': 22,
#     'cloudCover': 0.3,
#     'uvIndex': 1,
#     'visibility': 16.093,
#     'ozone': 346.9},
#    {'time': 1648112400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 11.49,
#     'apparentTemperature': 11.49,
#     'dewPoint': 4.63,
#     'humidity': 0.63,
#     'pressure': 1030.6,
#     'windSpeed': 4.24,
#     'windGust': 7.03,
#     'windBearing': 23,
#     'cloudCover': 0.34,
#     'uvIndex': 2,
#     'visibility': 16.093,
#     'ozone': 346.5},
#    {'time': 1648116000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 13.76,
#     'apparentTemperature': 13.76,
#     'dewPoint': 4.83,
#     'humidity': 0.55,
#     'pressure': 1030.7,
#     'windSpeed': 5.48,
#     'windGust': 7.68,
#     'windBearing': 25,
#     'cloudCover': 0.43,
#     'uvIndex': 2,
#     'visibility': 16.093,
#     'ozone': 349.7},
#    {'time': 1648119600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 15.37,
#     'apparentTemperature': 15.37,
#     'dewPoint': 4.56,
#     'humidity': 0.48,
#     'pressure': 1030.5,
#     'windSpeed': 6.88,
#     'windGust': 7.49,
#     'windBearing': 30,
#     'cloudCover': 0.43,
#     'uvIndex': 3,
#     'visibility': 16.093,
#     'ozone': 353.7},
#    {'time': 1648123200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 16.86,
#     'apparentTemperature': 16.86,
#     'dewPoint': 4.68,
#     'humidity': 0.44,
#     'pressure': 1030.2,
#     'windSpeed': 7.8,
#     'windGust': 7.8,
#     'windBearing': 36,
#     'cloudCover': 0.42,
#     'uvIndex': 3,
#     'visibility': 16.093,
#     'ozone': 352.5},
#    {'time': 1648126800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 17.69,
#     'apparentTemperature': 17.69,
#     'dewPoint': 4.42,
#     'humidity': 0.41,
#     'pressure': 1030,
#     'windSpeed': 9.02,
#     'windGust': 9.02,
#     'windBearing': 35,
#     'cloudCover': 0.39,
#     'uvIndex': 3,
#     'visibility': 16.093,
#     'ozone': 353.4},
#    {'time': 1648130400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 18.03,
#     'apparentTemperature': 18.03,
#     'dewPoint': 4.39,
#     'humidity': 0.4,
#     'pressure': 1029.3,
#     'windSpeed': 10.22,
#     'windGust': 10.22,
#     'windBearing': 33,
#     'cloudCover': 0.35,
#     'uvIndex': 2,
#     'visibility': 16.093,
#     'ozone': 353.7},
#    {'time': 1648134000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 17.65,
#     'apparentTemperature': 17.65,
#     'dewPoint': 4.49,
#     'humidity': 0.42,
#     'pressure': 1029,
#     'windSpeed': 11.27,
#     'windGust': 11.27,
#     'windBearing': 29,
#     'cloudCover': 0.39,
#     'uvIndex': 1,
#     'visibility': 16.093,
#     'ozone': 355.1},
#    {'time': 1648137600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 16.62,
#     'apparentTemperature': 16.62,
#     'dewPoint': 4.7,
#     'humidity': 0.45,
#     'pressure': 1028.8,
#     'windSpeed': 11.64,
#     'windGust': 12.17,
#     'windBearing': 25,
#     'cloudCover': 0.29,
#     'uvIndex': 1,
#     'visibility': 16.093,
#     'ozone': 355.8},
#    {'time': 1648141200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 14.82,
#     'apparentTemperature': 14.82,
#     'dewPoint': 4.55,
#     'humidity': 0.5,
#     'pressure': 1028.9,
#     'windSpeed': 11.57,
#     'windGust': 17.36,
#     'windBearing': 22,
#     'cloudCover': 0.25,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 354},
#    {'time': 1648144800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 12.87,
#     'apparentTemperature': 12.87,
#     'dewPoint': 3.87,
#     'humidity': 0.54,
#     'pressure': 1029.3,
#     'windSpeed': 11.25,
#     'windGust': 19.11,
#     'windBearing': 20,
#     'cloudCover': 0.37,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 352.5},
#    {'time': 1648148400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 11.29,
#     'apparentTemperature': 11.29,
#     'dewPoint': 3.66,
#     'humidity': 0.59,
#     'pressure': 1029.6,
#     'windSpeed': 10.84,
#     'windGust': 18.83,
#     'windBearing': 22,
#     'cloudCover': 0.47,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 350.2},
#    {'time': 1648152000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 9.97,
#     'apparentTemperature': 8.59,
#     'dewPoint': 3.59,
#     'humidity': 0.65,
#     'pressure': 1030,
#     'windSpeed': 10.15,
#     'windGust': 17.52,
#     'windBearing': 22,
#     'cloudCover': 0.47,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 348.2},
#    {'time': 1648155600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 8.99,
#     'apparentTemperature': 7.53,
#     'dewPoint': 3.78,
#     'humidity': 0.7,
#     'pressure': 1030.3,
#     'windSpeed': 9.51,
#     'windGust': 15.55,
#     'windBearing': 24,
#     'cloudCover': 0.4,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 344.3},
#    {'time': 1648159200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 8.27,
#     'apparentTemperature': 6.82,
#     'dewPoint': 4.02,
#     'humidity': 0.75,
#     'pressure': 1030.4,
#     'windSpeed': 8.73,
#     'windGust': 12.55,
#     'windBearing': 29,
#     'cloudCover': 0.33,
#     'uvIndex': 0,
#     'visibility': 16.093,
#     'ozone': 341}]},
#  'offset': 1}

# %%
route['steps'][0]['travel_mode']
# Out:
# 'WALKING'

# %%
num_journeys = 0
for i in range(len(json_resp['routes'])):
    route = json_resp['routes'][i]['legs'][0]
    if 'arrival_time' in route:
        print('yes')
        num_journeys += 1
        
num_journeys
# Out:
# yes
# yes
# yes
# 3

# %%
walk_time = 0
for step in route['steps']:
    if step['travel_mode'] == 'WALKING':
        walk_time += step['duration']['value']

# %%
round(walk_time / 60)
# Out:
# 43

# %%
g = geocoder.osm([52.3717958, 4.965470499999999], method='reverse')

# %%
print(g.street + g.housenumber)
# Out:
# Kees Broekmanstraat243
